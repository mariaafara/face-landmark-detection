# %%
feature_index = 4

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
cd gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !rm -rf face-landmark-detection
# !git clone --branch part2 https://github.com/mariaafara/face-landmark-detection.git
# Out:
# Cloning into 'face-landmark-detection'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 203 (delta 79), reused 166 (delta 43), pack-reused 0
# Receiving objects: 100% (203/203), 4.95 MiB | 19.14 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
cd face-landmark-detection/
# Out:
# /content/gdrive/MyDrive/face-landmark-detection

# %%
import os
os.environ['KAGGLE_USERNAME'] = "mariaafara" # username from the json file
os.environ['KAGGLE_KEY'] = "" # key from the json file
# Crearting a Client to host the Kaggle API
# !pip install -q kaggle
# !kaggle datasets download mariaafara/Facial-Landmarks
# !unzip Facial-Landmarks.zip # -d facial-keypoints-detection
# Out:
# Downloading Facial-Landmarks.zip to /content/gdrive/MyDrive/face-landmark-detection
#  97% 137M/141M [00:01<00:00, 63.5MB/s]
# 100% 141M/141M [00:01<00:00, 78.7MB/s]
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# Archive:  Facial-Landmarks.zip
#   inflating: dic_missing_data.pkl
#   inflating: dic_train_data.pkl

# %%
ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
from src.utils import *
dic_non_missing_data = load_from_pickle("dic_train_data.pkl")
features = list(dic_non_missing_data.keys())
feature_name = features[feature_index]
os.environ["EPOCHS"] = "100"
os.environ["RGB_CHANNELS"] = "false"
os.environ["PATIENCE_EARLY_STOPPING"] = "8"
# os.environ["PATIENCE_LR"] = "5"
path = F"/content/gdrive/My Drive/saved/"
os.environ["TRAIN_SCALER_PATH"] = "{}_scaler.pkl".format(path+feature_name)
os.environ["WEIGHT_PATH"] = "{}/weights/{}.ckpt".format(path+feature_name, feature_name)
os.environ["FEATURES_DIMENSIONS"] = "2"
os.environ["MODEL_PATH"] = "{}/model".format(path+feature_name)

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from src.config import prediction_model_config as config
from src.model.simple_model import MySimpleModel
from src.train import fit_model, compile_model
from src.data_preparation import DataGenerator
from IPython.display import clear_output
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# !pip install jedi==0.17.2

# %%
dic_non_missing_data[feature_name].head()
# Out:
#    right_eye_inner_corner_x  ...                                              Image
# 0                 36.356571  ...  [[238, 236, 237, 238, 240, 240, 239, 241, 241,...
# 1                 36.034723  ...  [[219, 215, 204, 196, 204, 211, 212, 200, 180,...
# 2                 37.678105  ...  [[144, 142, 159, 180, 188, 188, 184, 180, 167,...
# 3                 37.618643  ...  [[193, 192, 193, 194, 194, 194, 193, 192, 168,...
# 4                 36.982380  ...  [[147, 148, 160, 196, 215, 214, 216, 217, 219,...
#
# [5 rows x 3 columns]

# %%
df = dic_non_missing_data[feature_name]
df_train, df_test_val = split_data(df, test_size=0.3)
df_val, df_test = split_data(df_test_val, test_size=0.1)
print(df.shape, df_train.shape, df_val.shape, df_test.shape)

# fit the MinMaxScaler using the training data and then apply the scaler on the testing data before the prediction.
scaler = create_scaler(df_train.iloc[:,:-1])
save_to_pickle(scaler, config.TRAIN_SCALER_PATH)

train_generator = DataGenerator(df_train, 
                                batch_size=config.BATCH_SIZE,
                                augment= config.AUGMENT_TRAIN,
                                rgb_channels= config.RGB_CHANNELS,
                                normalize_image=config.NORMALIZE_IMAGE,
                                normalize_coordinates=config.NORMALIZE_COORDINATES, 
                                scaler=scaler)

val_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

test_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_VAL,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)
# Out:
# (2268, 3) (1587, 3) (612, 3) (69, 3)

# %%
my_model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)
compile_model(my_model, optimizer="adam", loss='mean_squared_error', metrics=['mae'])
my_model, history = fit_model(my_model, config.EPOCHS, train_generator, val_generator, config.WEIGHT_PATH)
# Out:
# Epoch 1/100
# 49/49 [==============================] - 5s 53ms/step - loss: 0.1174 - mae: 0.2537 - val_loss: 0.0239 - val_mae: 0.1172
#
# Epoch 00001: val_loss improved from inf to 0.02386, saving model to /content/gdrive/My Drive/saved/right_eye_inner_corner/weights/right_eye_inner_corner.ckpt
# Epoch 2/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0311 - mae: 0.1307 - val_loss: 0.0192 - val_mae: 0.1058
#
# Epoch 00002: val_loss improved from 0.02386 to 0.01915, saving model to /content/gdrive/My Drive/saved/right_eye_inner_corner/weights/right_eye_inner_corner.ckpt
# Epoch 3/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0220 - mae: 0.1088 - val_loss: 0.0206 - val_mae: 0.1004
#
# Epoch 00003: val_loss did not improve from 0.01915
# Epoch 4/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0183 - mae: 0.0997 - val_loss: 0.0166 - val_mae: 0.0982
#
# Epoch 00004: val_loss improved from 0.01915 to 0.01663, saving model to /content/gdrive/My Drive/saved/right_eye_inner_corner/weights/right_eye_inner_corner.ckpt
# Epoch 5/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0182 - mae: 0.0966 - val_loss: 0.0058 - val_mae: 0.0584
#
# Epoch 00005: val_loss improved from 0.01663 to 0.00585, saving model to /content/gdrive/My Drive/saved/right_eye_inner_corner/weights/right_eye_inner_corner.ckpt
# Epoch 6/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0131 - mae: 0.0844 - val_loss: 0.0096 - val_mae: 0.0715
#
# Epoch 00006: val_loss did not improve from 0.00585
# Epoch 7/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0140 - mae: 0.0840 - val_loss: 0.0108 - val_mae: 0.0772
#
# Epoch 00007: val_loss did not improve from 0.00585
# Epoch 8/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0144 - mae: 0.0856 - val_loss: 0.0069 - val_mae: 0.0597
#
# Epoch 00008: val_loss did not improve from 0.00585
# Epoch 9/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0124 - mae: 0.0806 - val_loss: 0.0077 - val_mae: 0.0679
#
# Epoch 00009: val_loss did not improve from 0.00585
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 10/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0100 - mae: 0.0733 - val_loss: 0.0081 - val_mae: 0.0628
#
# Epoch 00010: val_loss did not improve from 0.00585
# Epoch 11/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0098 - mae: 0.0692 - val_loss: 0.0046 - val_mae: 0.0498
#
# Epoch 00011: val_loss improved from 0.00585 to 0.00464, saving model to /content/gdrive/My Drive/saved/right_eye_inner_corner/weights/right_eye_inner_corner.ckpt
# Epoch 12/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0090 - mae: 0.0675 - val_loss: 0.0059 - val_mae: 0.0551
#
# Epoch 00012: val_loss did not improve from 0.00464
# Epoch 13/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0087 - mae: 0.0667 - val_loss: 0.0045 - val_mae: 0.0469
#
# Epoch 00013: val_loss improved from 0.00464 to 0.00454, saving model to /content/gdrive/My Drive/saved/right_eye_inner_corner/weights/right_eye_inner_corner.ckpt
# Epoch 14/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0084 - mae: 0.0657 - val_loss: 0.0047 - val_mae: 0.0491
#
# Epoch 00014: val_loss did not improve from 0.00454
# Epoch 15/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0081 - mae: 0.0656 - val_loss: 0.0050 - val_mae: 0.0530
#
# Epoch 00015: val_loss did not improve from 0.00454
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 16/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0072 - mae: 0.0608 - val_loss: 0.0049 - val_mae: 0.0526
#
# Epoch 00016: val_loss did not improve from 0.00454
# Epoch 17/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0075 - mae: 0.0613 - val_loss: 0.0052 - val_mae: 0.0512
#
# Epoch 00017: val_loss did not improve from 0.00454
# Epoch 18/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0075 - mae: 0.0616 - val_loss: 0.0040 - val_mae: 0.0468
#
# Epoch 00018: val_loss improved from 0.00454 to 0.00398, saving model to /content/gdrive/My Drive/saved/right_eye_inner_corner/weights/right_eye_inner_corner.ckpt
# Epoch 19/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0088 - mae: 0.0660 - val_loss: 0.0036 - val_mae: 0.0455
#
# Epoch 00019: val_loss improved from 0.00398 to 0.00362, saving model to /content/gdrive/My Drive/saved/right_eye_inner_corner/weights/right_eye_inner_corner.ckpt
# Epoch 20/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0078 - mae: 0.0614 - val_loss: 0.0063 - val_mae: 0.0554
#
# Epoch 00020: val_loss did not improve from 0.00362
# Epoch 21/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0074 - mae: 0.0605 - val_loss: 0.0032 - val_mae: 0.0428
#
# Epoch 00021: val_loss improved from 0.00362 to 0.00320, saving model to /content/gdrive/My Drive/saved/right_eye_inner_corner/weights/right_eye_inner_corner.ckpt
# Epoch 22/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0079 - mae: 0.0639 - val_loss: 0.0036 - val_mae: 0.0461
#
# Epoch 00022: val_loss did not improve from 0.00320
# Epoch 23/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0078 - mae: 0.0633 - val_loss: 0.0056 - val_mae: 0.0495
#
# Epoch 00023: val_loss did not improve from 0.00320
# Epoch 24/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0064 - mae: 0.0591 - val_loss: 0.0054 - val_mae: 0.0534
#
# Epoch 00024: val_loss did not improve from 0.00320
# Epoch 25/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0075 - mae: 0.0620 - val_loss: 0.0038 - val_mae: 0.0475
#
# Epoch 00025: val_loss did not improve from 0.00320
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 26/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0077 - mae: 0.0603 - val_loss: 0.0077 - val_mae: 0.0575
#
# Epoch 00026: val_loss did not improve from 0.00320
# Epoch 27/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0078 - mae: 0.0616 - val_loss: 0.0035 - val_mae: 0.0421
#
# Epoch 00027: val_loss did not improve from 0.00320
# Epoch 28/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0071 - mae: 0.0616 - val_loss: 0.0042 - val_mae: 0.0498
#
# Epoch 00028: val_loss did not improve from 0.00320
# Epoch 29/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0075 - mae: 0.0628 - val_loss: 0.0035 - val_mae: 0.0452
#
# Epoch 00029: val_loss did not improve from 0.00320
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 00029: early stopping

# %%
# Recreat the same structure of the model and load its saved weights then build it by predicting a random input then save the model
from src.train import compile_model
from tensorflow.keras.models import load_model

model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)

model.load_weights(config.WEIGHT_PATH)
model.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
model.save(config.MODEL_PATH)
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/saved/right_eye_inner_corner/model/assets

# %%
# load the model to check it
m = load_model(config.MODEL_PATH, compile=False)
m.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
# Out:
# array([[0.41490132, 0.30752566]], dtype=float32)

# %%
compile_model(m)
m.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0532 - mae: 0.0329
# [0.05555866286158562, 0.03421387821435928]

# %% [markdown]
# #### **Evaluate the model**

# %%
my_model.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0017 - mae: 0.0321
# [0.0017484069103375077, 0.032132647931575775]

# %%
# Retrieve a list of list results on training and test data sets for each training epoch
loss     = history.history['loss']
val_loss = history.history['val_loss']
epochs   = range(len(loss))
# Plot training and validation loss per epoch
plt.plot(epochs,loss, color='red' , label='training loss')
plt.plot(epochs, val_loss, label='validation loss')
plt.legend()
plt.title ('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
test_generator_with_augmentation =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

# %%
batch = test_generator_with_augmentation.__getitem__(1)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_augmented_results.png", "augmented")

# %%
batch = test_generator.__getitem__(1)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_normal_results.png", "normal")
