# %%
feature_index = 13

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
cd gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !rm -rf face-landmark-detection
# !git clone --branch part2 https://github.com/mariaafara/face-landmark-detection.git
# Out:
# Cloning into 'face-landmark-detection'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 203 (delta 79), reused 166 (delta 43), pack-reused 0
# Receiving objects: 100% (203/203), 4.95 MiB | 19.97 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
cd face-landmark-detection/
# Out:
# /content/gdrive/MyDrive/face-landmark-detection

# %%
import os
os.environ['KAGGLE_USERNAME'] = "mariaafara" # username from the json file
os.environ['KAGGLE_KEY'] = "" # key from the json file
# Crearting a Client to host the Kaggle API
# !pip install -q kaggle
# !kaggle datasets download mariaafara/Facial-Landmarks
# !unzip Facial-Landmarks.zip # -d facial-keypoints-detection
# Out:
# Downloading Facial-Landmarks.zip to /content/gdrive/MyDrive/face-landmark-detection
#  92% 129M/141M [00:01<00:00, 102MB/s]
# 100% 141M/141M [00:01<00:00, 126MB/s]
# Archive:  Facial-Landmarks.zip
#   inflating: dic_missing_data.pkl
#   inflating: dic_train_data.pkl

# %%
ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
# %ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
from src.utils import *
dic_non_missing_data = load_from_pickle("dic_train_data.pkl")
features = list(dic_non_missing_data.keys())
feature_name = features[feature_index]
os.environ["EPOCHS"] = "100"
os.environ["RGB_CHANNELS"] = "false"
os.environ["PATIENCE_EARLY_STOPPING"] = "8"
# os.environ["PATIENCE_LR"] = "5"
path = F"/content/gdrive/My Drive/saved/"
os.environ["TRAIN_SCALER_PATH"] = "{}_scaler.pkl".format(path+feature_name)
os.environ["WEIGHT_PATH"] = "{}/weights/{}.ckpt".format(path+feature_name, feature_name)
os.environ["FEATURES_DIMENSIONS"] = "2"
os.environ["MODEL_PATH"] = "{}/model".format(path+feature_name)

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from src.config import prediction_model_config as config
from src.model.simple_model import MySimpleModel
from src.train import fit_model, compile_model
from src.data_preparation import DataGenerator
from IPython.display import clear_output
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# !pip install jedi==0.17.2

# %%
dic_non_missing_data[feature_name].head()
# Out:
#    mouth_center_bottom_lip_x  ...                                              Image
# 0                  43.130707  ...  [[238, 236, 237, 238, 240, 240, 239, 241, 241,...
# 1                  45.467915  ...  [[219, 215, 204, 196, 204, 211, 212, 200, 180,...
# 2                  47.274947  ...  [[144, 142, 159, 180, 188, 188, 184, 180, 167,...
# 3                  51.561183  ...  [[193, 192, 193, 194, 194, 194, 193, 192, 168,...
# 4                  44.227141  ...  [[147, 148, 160, 196, 215, 214, 216, 217, 219,...
#
# [5 rows x 3 columns]

# %%
df = dic_non_missing_data[feature_name]
df_train, df_test_val = split_data(df, test_size=0.3)
df_val, df_test = split_data(df_test_val, test_size=0.1)
print(df.shape, df_train.shape, df_val.shape, df_test.shape)

# fit the MinMaxScaler using the training data and then apply the scaler on the testing data before the prediction.
scaler = create_scaler(df_train.iloc[:,:-1])
save_to_pickle(scaler, config.TRAIN_SCALER_PATH)

train_generator = DataGenerator(df_train, 
                                batch_size=config.BATCH_SIZE,
                                augment= config.AUGMENT_TRAIN,
                                rgb_channels= config.RGB_CHANNELS,
                                normalize_image=config.NORMALIZE_IMAGE,
                                normalize_coordinates=config.NORMALIZE_COORDINATES, 
                                scaler=scaler)

val_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

test_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_VAL,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)
# Out:
# (7016, 3) (4911, 3) (1894, 3) (211, 3)

# %%
my_model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)
compile_model(my_model, optimizer="adam", loss='mean_squared_error', metrics=['mae'])
my_model, history = fit_model(my_model, config.EPOCHS, train_generator, val_generator, config.WEIGHT_PATH)
# Out:
# Epoch 1/100
# 153/153 [==============================] - 12s 55ms/step - loss: 0.0654 - mae: 0.1820 - val_loss: 0.0083 - val_mae: 0.0730
#
# Epoch 00001: val_loss improved from inf to 0.00827, saving model to /content/gdrive/My Drive/saved/mouth_center_bottom_lip/weights/mouth_center_bottom_lip.ckpt
# Epoch 2/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0100 - mae: 0.0770 - val_loss: 0.0067 - val_mae: 0.0639
#
# Epoch 00002: val_loss improved from 0.00827 to 0.00666, saving model to /content/gdrive/My Drive/saved/mouth_center_bottom_lip/weights/mouth_center_bottom_lip.ckpt
# Epoch 3/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0079 - mae: 0.0682 - val_loss: 0.0052 - val_mae: 0.0550
#
# Epoch 00003: val_loss improved from 0.00666 to 0.00517, saving model to /content/gdrive/My Drive/saved/mouth_center_bottom_lip/weights/mouth_center_bottom_lip.ckpt
# Epoch 4/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0072 - mae: 0.0644 - val_loss: 0.0056 - val_mae: 0.0541
#
# Epoch 00004: val_loss did not improve from 0.00517
# Epoch 5/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0059 - mae: 0.0585 - val_loss: 0.0054 - val_mae: 0.0552
#
# Epoch 00005: val_loss did not improve from 0.00517
# Epoch 6/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0057 - mae: 0.0566 - val_loss: 0.0055 - val_mae: 0.0534
#
# Epoch 00006: val_loss did not improve from 0.00517
# Epoch 7/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0052 - mae: 0.0544 - val_loss: 0.0050 - val_mae: 0.0511
#
# Epoch 00007: val_loss improved from 0.00517 to 0.00502, saving model to /content/gdrive/My Drive/saved/mouth_center_bottom_lip/weights/mouth_center_bottom_lip.ckpt
# Epoch 8/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0051 - mae: 0.0538 - val_loss: 0.0045 - val_mae: 0.0508
#
# Epoch 00008: val_loss improved from 0.00502 to 0.00447, saving model to /content/gdrive/My Drive/saved/mouth_center_bottom_lip/weights/mouth_center_bottom_lip.ckpt
# Epoch 9/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0050 - mae: 0.0528 - val_loss: 0.0032 - val_mae: 0.0435
#
# Epoch 00009: val_loss improved from 0.00447 to 0.00316, saving model to /content/gdrive/My Drive/saved/mouth_center_bottom_lip/weights/mouth_center_bottom_lip.ckpt
# Epoch 10/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0048 - mae: 0.0515 - val_loss: 0.0038 - val_mae: 0.0448
#
# Epoch 00010: val_loss did not improve from 0.00316
# Epoch 11/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0044 - mae: 0.0500 - val_loss: 0.0042 - val_mae: 0.0479
#
# Epoch 00011: val_loss did not improve from 0.00316
# Epoch 12/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0046 - mae: 0.0506 - val_loss: 0.0036 - val_mae: 0.0446
#
# Epoch 00012: val_loss did not improve from 0.00316
# Epoch 13/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0048 - mae: 0.0502 - val_loss: 0.0033 - val_mae: 0.0445
#
# Epoch 00013: val_loss did not improve from 0.00316
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 14/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0041 - mae: 0.0468 - val_loss: 0.0033 - val_mae: 0.0405
#
# Epoch 00014: val_loss did not improve from 0.00316
# Epoch 15/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0036 - mae: 0.0437 - val_loss: 0.0025 - val_mae: 0.0363
#
# Epoch 00015: val_loss improved from 0.00316 to 0.00248, saving model to /content/gdrive/My Drive/saved/mouth_center_bottom_lip/weights/mouth_center_bottom_lip.ckpt
# Epoch 16/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0036 - mae: 0.0443 - val_loss: 0.0032 - val_mae: 0.0398
#
# Epoch 00016: val_loss did not improve from 0.00248
# Epoch 17/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0033 - mae: 0.0425 - val_loss: 0.0028 - val_mae: 0.0390
#
# Epoch 00017: val_loss did not improve from 0.00248
# Epoch 18/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0036 - mae: 0.0444 - val_loss: 0.0027 - val_mae: 0.0360
#
# Epoch 00018: val_loss did not improve from 0.00248
# Epoch 19/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0035 - mae: 0.0435 - val_loss: 0.0025 - val_mae: 0.0375
#
# Epoch 00019: val_loss improved from 0.00248 to 0.00246, saving model to /content/gdrive/My Drive/saved/mouth_center_bottom_lip/weights/mouth_center_bottom_lip.ckpt
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 20/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0032 - mae: 0.0422 - val_loss: 0.0026 - val_mae: 0.0359
#
# Epoch 00020: val_loss did not improve from 0.00246
# Epoch 21/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0032 - mae: 0.0419 - val_loss: 0.0023 - val_mae: 0.0350
#
# Epoch 00021: val_loss improved from 0.00246 to 0.00233, saving model to /content/gdrive/My Drive/saved/mouth_center_bottom_lip/weights/mouth_center_bottom_lip.ckpt
# Epoch 22/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0032 - mae: 0.0417 - val_loss: 0.0022 - val_mae: 0.0350
#
# Epoch 00022: val_loss improved from 0.00233 to 0.00224, saving model to /content/gdrive/My Drive/saved/mouth_center_bottom_lip/weights/mouth_center_bottom_lip.ckpt
# Epoch 23/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0031 - mae: 0.0412 - val_loss: 0.0024 - val_mae: 0.0359
#
# Epoch 00023: val_loss did not improve from 0.00224
# Epoch 24/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0033 - mae: 0.0420 - val_loss: 0.0026 - val_mae: 0.0349
#
# Epoch 00024: val_loss did not improve from 0.00224
# Epoch 25/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0033 - mae: 0.0418 - val_loss: 0.0025 - val_mae: 0.0362
#
# Epoch 00025: val_loss did not improve from 0.00224
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 26/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0032 - mae: 0.0418 - val_loss: 0.0022 - val_mae: 0.0359
#
# Epoch 00026: val_loss improved from 0.00224 to 0.00222, saving model to /content/gdrive/My Drive/saved/mouth_center_bottom_lip/weights/mouth_center_bottom_lip.ckpt
# Epoch 27/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0031 - mae: 0.0410 - val_loss: 0.0022 - val_mae: 0.0354
#
# Epoch 00027: val_loss improved from 0.00222 to 0.00216, saving model to /content/gdrive/My Drive/saved/mouth_center_bottom_lip/weights/mouth_center_bottom_lip.ckpt
# Epoch 28/100
# 153/153 [==============================] - 7s 48ms/step - loss: 0.0033 - mae: 0.0422 - val_loss: 0.0026 - val_mae: 0.0375
#
# Epoch 00028: val_loss did not improve from 0.00216
# Epoch 29/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0031 - mae: 0.0406 - val_loss: 0.0024 - val_mae: 0.0358
#
# Epoch 00029: val_loss did not improve from 0.00216
# Epoch 30/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0032 - mae: 0.0418 - val_loss: 0.0025 - val_mae: 0.0358
#
# Epoch 00030: val_loss did not improve from 0.00216
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 31/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0031 - mae: 0.0410 - val_loss: 0.0023 - val_mae: 0.0356
#
# Epoch 00031: val_loss did not improve from 0.00216
# Epoch 32/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0030 - mae: 0.0406 - val_loss: 0.0022 - val_mae: 0.0364
#
# Epoch 00032: val_loss did not improve from 0.00216
# Epoch 33/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0030 - mae: 0.0413 - val_loss: 0.0022 - val_mae: 0.0356
#
# Epoch 00033: val_loss did not improve from 0.00216
# Epoch 34/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0030 - mae: 0.0402 - val_loss: 0.0028 - val_mae: 0.0363
#
# Epoch 00034: val_loss did not improve from 0.00216
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 35/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0032 - mae: 0.0413 - val_loss: 0.0022 - val_mae: 0.0352
#
# Epoch 00035: val_loss did not improve from 0.00216
# Epoch 00035: early stopping

# %%
# Recreat the same structure of the model and load its saved weights then build it by predicting a random input then save the model
from src.train import compile_model
from tensorflow.keras.models import load_model

model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)

model.load_weights(config.WEIGHT_PATH)
model.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
model.save(config.MODEL_PATH)
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/saved/mouth_center_bottom_lip/model/assets

# %%
# load the model to check it
m = load_model(config.MODEL_PATH, compile=False)
m.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
# Out:
# array([[0.39043733, 0.7007315 ]], dtype=float32)

# %%
compile_model(m)
m.evaluate(test_generator)
# Out:
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0442 - mae: 0.0279
# [0.04565351828932762, 0.028760166838765144]

# %% [markdown]
# #### **Evaluate the model**

# %%
my_model.evaluate(test_generator)
# Out:
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0015 - mae: 0.0288
# [0.001509884255938232, 0.02877664566040039]

# %%
# Retrieve a list of list results on training and test data sets for each training epoch
loss     = history.history['loss']
val_loss = history.history['val_loss']
epochs   = range(len(loss))
# Plot training and validation loss per epoch
plt.plot(epochs,loss, color='red' , label='training loss')
plt.plot(epochs, val_loss, label='validation loss')
plt.legend()
plt.title ('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
test_generator_with_augmentation =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

# %%
batch = test_generator_with_augmentation.__getitem__(0)
visualize_random_predicted_images(m, batch, scaler, feature_name, path+feature_name+"_augmented_results.png", "augmented")

# %%
batch = test_generator.__getitem__(0)
visualize_random_predicted_images(m, batch, scaler, feature_name, path+feature_name+"_normal_results.png", "normal")
