# %%
feature_index = 9

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
cd gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !rm -rf face-landmark-detection
# !git clone --branch part2 https://github.com/mariaafara/face-landmark-detection.git
# Out:
# Cloning into 'face-landmark-detection'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 203 (delta 79), reused 166 (delta 43), pack-reused 0
# Receiving objects: 100% (203/203), 4.95 MiB | 18.51 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
cd face-landmark-detection/
# Out:
# /content/gdrive/MyDrive/face-landmark-detection

# %%
import os
os.environ['KAGGLE_USERNAME'] = "mariaafara" # username from the json file
os.environ['KAGGLE_KEY'] = "" # key from the json file
# Crearting a Client to host the Kaggle API
# !pip install -q kaggle
# !kaggle datasets download mariaafara/Facial-Landmarks
# !unzip Facial-Landmarks.zip # -d facial-keypoints-detection
# Out:
# Downloading Facial-Landmarks.zip to /content/gdrive/MyDrive/face-landmark-detection
#  97% 136M/141M [00:01<00:00, 75.9MB/s]
# 100% 141M/141M [00:01<00:00, 111MB/s]
# Archive:  Facial-Landmarks.zip
#   inflating: dic_missing_data.pkl
#   inflating: dic_train_data.pkl

# %%
ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
# %ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
from src.utils import *
dic_non_missing_data = load_from_pickle("dic_train_data.pkl")
features = list(dic_non_missing_data.keys())
feature_name = features[feature_index]
os.environ["EPOCHS"] = "100"
os.environ["RGB_CHANNELS"] = "false"
os.environ["PATIENCE_EARLY_STOPPING"] = "8"
# os.environ["PATIENCE_LR"] = "5"
path = F"/content/gdrive/My Drive/saved/"
os.environ["TRAIN_SCALER_PATH"] = "{}_scaler.pkl".format(path+feature_name)
os.environ["WEIGHT_PATH"] = "{}/weights/{}.ckpt".format(path+feature_name, feature_name)
os.environ["FEATURES_DIMENSIONS"] = "2"
os.environ["MODEL_PATH"] = "{}/model".format(path+feature_name)

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from src.config import prediction_model_config as config
from src.model.simple_model import MySimpleModel
from src.train import fit_model, compile_model
from src.data_preparation import DataGenerator
from IPython.display import clear_output
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# !pip install jedi==0.17.2

# %%
dic_non_missing_data[feature_name].head()
# Out:
#    right_eyebrow_outer_end_x  ...                                              Image
# 0                  16.356379  ...  [[238, 236, 237, 238, 240, 240, 239, 241, 241,...
# 1                  16.865362  ...  [[219, 215, 204, 196, 204, 211, 212, 200, 180,...
# 2                  16.791158  ...  [[144, 142, 159, 180, 188, 188, 184, 180, 167,...
# 3                  20.458017  ...  [[193, 192, 193, 194, 194, 194, 193, 192, 168,...
# 4                  15.925870  ...  [[147, 148, 160, 196, 215, 214, 216, 217, 219,...
#
# [5 rows x 3 columns]

# %%
df = dic_non_missing_data[feature_name]
df_train, df_test_val = split_data(df, test_size=0.3)
df_val, df_test = split_data(df_test_val, test_size=0.1)
print(df.shape, df_train.shape, df_val.shape, df_test.shape)

# fit the MinMaxScaler using the training data and then apply the scaler on the testing data before the prediction.
scaler = create_scaler(df_train.iloc[:,:-1])
save_to_pickle(scaler, config.TRAIN_SCALER_PATH)

train_generator = DataGenerator(df_train, 
                                batch_size=config.BATCH_SIZE,
                                augment= config.AUGMENT_TRAIN,
                                rgb_channels= config.RGB_CHANNELS,
                                normalize_image=config.NORMALIZE_IMAGE,
                                normalize_coordinates=config.NORMALIZE_COORDINATES, 
                                scaler=scaler)

val_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

test_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_VAL,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)
# Out:
# (2236, 3) (1565, 3) (603, 3) (68, 3)

# %%
my_model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)
compile_model(my_model, optimizer="adam", loss='mean_squared_error', metrics=['mae'])
my_model, history = fit_model(my_model, config.EPOCHS, train_generator, val_generator, config.WEIGHT_PATH)
# Out:
# Epoch 1/100
# 48/48 [==============================] - 3s 52ms/step - loss: 0.0521 - mae: 0.1755 - val_loss: 0.0179 - val_mae: 0.1019
#
# Epoch 00001: val_loss improved from inf to 0.01790, saving model to /content/gdrive/My Drive/saved/right_eyebrow_outer_end/weights/right_eyebrow_outer_end.ckpt
# Epoch 2/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0174 - mae: 0.1004 - val_loss: 0.0120 - val_mae: 0.0793
#
# Epoch 00002: val_loss improved from 0.01790 to 0.01202, saving model to /content/gdrive/My Drive/saved/right_eyebrow_outer_end/weights/right_eyebrow_outer_end.ckpt
# Epoch 3/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0129 - mae: 0.0849 - val_loss: 0.0084 - val_mae: 0.0678
#
# Epoch 00003: val_loss improved from 0.01202 to 0.00842, saving model to /content/gdrive/My Drive/saved/right_eyebrow_outer_end/weights/right_eyebrow_outer_end.ckpt
# Epoch 4/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0110 - mae: 0.0797 - val_loss: 0.0085 - val_mae: 0.0696
#
# Epoch 00004: val_loss did not improve from 0.00842
# Epoch 5/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0090 - mae: 0.0704 - val_loss: 0.0087 - val_mae: 0.0681
#
# Epoch 00005: val_loss did not improve from 0.00842
# Epoch 6/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0082 - mae: 0.0677 - val_loss: 0.0087 - val_mae: 0.0647
#
# Epoch 00006: val_loss did not improve from 0.00842
# Epoch 7/100
# 48/48 [==============================] - 2s 51ms/step - loss: 0.0084 - mae: 0.0675 - val_loss: 0.0096 - val_mae: 0.0699
#
# Epoch 00007: val_loss did not improve from 0.00842
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 8/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0070 - mae: 0.0622 - val_loss: 0.0057 - val_mae: 0.0532
#
# Epoch 00008: val_loss improved from 0.00842 to 0.00571, saving model to /content/gdrive/My Drive/saved/right_eyebrow_outer_end/weights/right_eyebrow_outer_end.ckpt
# Epoch 9/100
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0065 - mae: 0.0585 - val_loss: 0.0055 - val_mae: 0.0519
#
# Epoch 00009: val_loss improved from 0.00571 to 0.00550, saving model to /content/gdrive/My Drive/saved/right_eyebrow_outer_end/weights/right_eyebrow_outer_end.ckpt
# Epoch 10/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0064 - mae: 0.0597 - val_loss: 0.0070 - val_mae: 0.0577
#
# Epoch 00010: val_loss did not improve from 0.00550
# Epoch 11/100
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0061 - mae: 0.0570 - val_loss: 0.0062 - val_mae: 0.0549
#
# Epoch 00011: val_loss did not improve from 0.00550
# Epoch 12/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0053 - mae: 0.0540 - val_loss: 0.0065 - val_mae: 0.0591
#
# Epoch 00012: val_loss did not improve from 0.00550
# Epoch 13/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0061 - mae: 0.0558 - val_loss: 0.0048 - val_mae: 0.0500
#
# Epoch 00013: val_loss improved from 0.00550 to 0.00484, saving model to /content/gdrive/My Drive/saved/right_eyebrow_outer_end/weights/right_eyebrow_outer_end.ckpt
# Epoch 14/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0054 - mae: 0.0537 - val_loss: 0.0054 - val_mae: 0.0490
#
# Epoch 00014: val_loss did not improve from 0.00484
# Epoch 15/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0055 - mae: 0.0547 - val_loss: 0.0058 - val_mae: 0.0526
#
# Epoch 00015: val_loss did not improve from 0.00484
# Epoch 16/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0056 - mae: 0.0543 - val_loss: 0.0047 - val_mae: 0.0476
#
# Epoch 00016: val_loss improved from 0.00484 to 0.00472, saving model to /content/gdrive/My Drive/saved/right_eyebrow_outer_end/weights/right_eyebrow_outer_end.ckpt
# Epoch 17/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0054 - mae: 0.0540 - val_loss: 0.0054 - val_mae: 0.0478
#
# Epoch 00017: val_loss did not improve from 0.00472
# Epoch 18/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0055 - mae: 0.0530 - val_loss: 0.0061 - val_mae: 0.0559
#
# Epoch 00018: val_loss did not improve from 0.00472
# Epoch 19/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0055 - mae: 0.0546 - val_loss: 0.0043 - val_mae: 0.0453
#
# Epoch 00019: val_loss improved from 0.00472 to 0.00427, saving model to /content/gdrive/My Drive/saved/right_eyebrow_outer_end/weights/right_eyebrow_outer_end.ckpt
# Epoch 20/100
# 48/48 [==============================] - 2s 49ms/step - loss: 0.0051 - mae: 0.0524 - val_loss: 0.0055 - val_mae: 0.0522
#
# Epoch 00020: val_loss did not improve from 0.00427
# Epoch 21/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0050 - mae: 0.0520 - val_loss: 0.0053 - val_mae: 0.0523
#
# Epoch 00021: val_loss did not improve from 0.00427
# Epoch 22/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0055 - mae: 0.0546 - val_loss: 0.0050 - val_mae: 0.0501
#
# Epoch 00022: val_loss did not improve from 0.00427
# Epoch 23/100
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0055 - mae: 0.0524 - val_loss: 0.0057 - val_mae: 0.0511
#
# Epoch 00023: val_loss did not improve from 0.00427
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 24/100
# 48/48 [==============================] - 2s 49ms/step - loss: 0.0052 - mae: 0.0513 - val_loss: 0.0054 - val_mae: 0.0470
#
# Epoch 00024: val_loss did not improve from 0.00427
# Epoch 25/100
# 48/48 [==============================] - 2s 49ms/step - loss: 0.0044 - mae: 0.0486 - val_loss: 0.0051 - val_mae: 0.0509
#
# Epoch 00025: val_loss did not improve from 0.00427
# Epoch 26/100
# 48/48 [==============================] - 2s 49ms/step - loss: 0.0048 - mae: 0.0497 - val_loss: 0.0044 - val_mae: 0.0483
#
# Epoch 00026: val_loss did not improve from 0.00427
# Epoch 27/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0046 - mae: 0.0493 - val_loss: 0.0054 - val_mae: 0.0517
#
# Epoch 00027: val_loss did not improve from 0.00427
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 00027: early stopping

# %%
# Recreat the same structure of the model and load its saved weights then build it by predicting a random input then save the model
from src.train import compile_model
from tensorflow.keras.models import load_model

model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)

model.load_weights(config.WEIGHT_PATH)
model.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
model.save(config.MODEL_PATH)
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/saved/right_eyebrow_outer_end/model/assets

# %%
# load the model to check it
m = load_model(config.MODEL_PATH, compile=False)
m.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))

# %%
compile_model(m)
m.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0593 - mae: 0.0371
# [0.06053706258535385, 0.0375346839427948]

# %% [markdown]
# #### **Evaluate the model**

# %%
my_model.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0037 - mae: 0.0385
# [0.003684127004817128, 0.03851192444562912]

# %%
# Retrieve a list of list results on training and test data sets for each training epoch
loss     = history.history['loss']
val_loss = history.history['val_loss']
epochs   = range(len(loss))
# Plot training and validation loss per epoch
plt.plot(epochs,loss, color='red' , label='training loss')
plt.plot(epochs, val_loss, label='validation loss')
plt.legend()
plt.title ('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
test_generator_with_augmentation =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

# %%
batch = test_generator_with_augmentation.__getitem__(0)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_augmented_results.png", "augmented")

# %%
batch = test_generator.__getitem__(0)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_normal_results.png", "normal")
