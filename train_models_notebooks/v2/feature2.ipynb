# %%
feature_index = 2

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
cd gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !rm -rf face-landmark-detection
# !git clone --branch part2 https://github.com/mariaafara/face-landmark-detection.git
# Out:
# Cloning into 'face-landmark-detection'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 203 (delta 79), reused 166 (delta 43), pack-reused 0
# Receiving objects: 100% (203/203), 4.95 MiB | 18.93 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
cd face-landmark-detection/
# Out:
# /content/gdrive/MyDrive/face-landmark-detection

# %%
import os
os.environ['KAGGLE_USERNAME'] = "mariaafara" # username from the json file
os.environ['KAGGLE_KEY'] = "" # key from the json file
# Crearting a Client to host the Kaggle API
# !pip install -q kaggle
# !kaggle datasets download mariaafara/Facial-Landmarks
# !unzip Facial-Landmarks.zip # -d facial-keypoints-detection
# Out:
# Downloading Facial-Landmarks.zip to /content/gdrive/MyDrive/face-landmark-detection
#  92% 129M/141M [00:01<00:00, 37.0MB/s]
# 100% 141M/141M [00:02<00:00, 73.1MB/s]
# Archive:  Facial-Landmarks.zip
#   inflating: dic_missing_data.pkl
#   inflating: dic_train_data.pkl

# %%
ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
from src.utils import *
dic_non_missing_data = load_from_pickle("dic_train_data.pkl")
features = list(dic_non_missing_data.keys())
feature_name = features[feature_index]
os.environ["EPOCHS"] = "100"
os.environ["RGB_CHANNELS"] = "false"
os.environ["PATIENCE_EARLY_STOPPING"] = "8"
# os.environ["PATIENCE_LR"] = "5"
path = F"/content/gdrive/My Drive/saved/"
os.environ["TRAIN_SCALER_PATH"] = "{}_scaler.pkl".format(path+feature_name)
os.environ["WEIGHT_PATH"] = "{}/weights/{}.ckpt".format(path+feature_name, feature_name)
os.environ["FEATURES_DIMENSIONS"] = "2"
os.environ["MODEL_PATH"] = "{}/model".format(path+feature_name)

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from src.config import prediction_model_config as config
from src.model.simple_model import MySimpleModel
from src.train import fit_model, compile_model
from src.data_preparation import DataGenerator
from IPython.display import clear_output
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# !pip install jedi==0.17.2

# %%
dic_non_missing_data[feature_name].head()
# Out:
#    left_eye_inner_corner_x  ...                                              Image
# 0                59.582075  ...  [[238, 236, 237, 238, 240, 240, 239, 241, 241,...
# 1                58.856170  ...  [[219, 215, 204, 196, 204, 211, 212, 200, 180,...
# 2                59.412000  ...  [[144, 142, 159, 180, 188, 188, 184, 180, 167,...
# 3                60.003339  ...  [[193, 192, 193, 194, 194, 194, 193, 192, 168,...
# 4                58.565890  ...  [[147, 148, 160, 196, 215, 214, 216, 217, 219,...
#
# [5 rows x 3 columns]

# %%
df = dic_non_missing_data[feature_name]
df_train, df_test_val = split_data(df, test_size=0.3)
df_val, df_test = split_data(df_test_val, test_size=0.1)
print(df.shape, df_train.shape, df_val.shape, df_test.shape)

# fit the MinMaxScaler using the training data and then apply the scaler on the testing data before the prediction.
scaler = create_scaler(df_train.iloc[:,:-1])
save_to_pickle(scaler, config.TRAIN_SCALER_PATH)

train_generator = DataGenerator(df_train, 
                                batch_size=config.BATCH_SIZE,
                                augment= config.AUGMENT_TRAIN,
                                rgb_channels= config.RGB_CHANNELS,
                                normalize_image=config.NORMALIZE_IMAGE,
                                normalize_coordinates=config.NORMALIZE_COORDINATES, 
                                scaler=scaler)

val_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

test_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_VAL,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)
# Out:
# (2271, 3) (1589, 3) (613, 3) (69, 3)

# %%
my_model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)
compile_model(my_model, optimizer="adam", loss='mean_squared_error', metrics=['mae'])
my_model, history = fit_model(my_model, config.EPOCHS, train_generator, val_generator, config.WEIGHT_PATH)
# Out:
# Epoch 1/100
# 49/49 [==============================] - 6s 65ms/step - loss: 0.0889 - mae: 0.2310 - val_loss: 0.0265 - val_mae: 0.1254
#
# Epoch 00001: val_loss improved from inf to 0.02649, saving model to /content/gdrive/My Drive/saved/left_eye_inner_corner/weights/left_eye_inner_corner.ckpt
# Epoch 2/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0226 - mae: 0.1121 - val_loss: 0.0119 - val_mae: 0.0819
#
# Epoch 00002: val_loss improved from 0.02649 to 0.01186, saving model to /content/gdrive/My Drive/saved/left_eye_inner_corner/weights/left_eye_inner_corner.ckpt
# Epoch 3/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0143 - mae: 0.0897 - val_loss: 0.0090 - val_mae: 0.0766
#
# Epoch 00003: val_loss improved from 0.01186 to 0.00902, saving model to /content/gdrive/My Drive/saved/left_eye_inner_corner/weights/left_eye_inner_corner.ckpt
# Epoch 4/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0114 - mae: 0.0796 - val_loss: 0.0084 - val_mae: 0.0697
#
# Epoch 00004: val_loss improved from 0.00902 to 0.00843, saving model to /content/gdrive/My Drive/saved/left_eye_inner_corner/weights/left_eye_inner_corner.ckpt
# Epoch 5/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0111 - mae: 0.0774 - val_loss: 0.0051 - val_mae: 0.0494
#
# Epoch 00005: val_loss improved from 0.00843 to 0.00507, saving model to /content/gdrive/My Drive/saved/left_eye_inner_corner/weights/left_eye_inner_corner.ckpt
# Epoch 6/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0095 - mae: 0.0719 - val_loss: 0.0057 - val_mae: 0.0546
#
# Epoch 00006: val_loss did not improve from 0.00507
# Epoch 7/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0086 - mae: 0.0681 - val_loss: 0.0052 - val_mae: 0.0559
#
# Epoch 00007: val_loss did not improve from 0.00507
# Epoch 8/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0088 - mae: 0.0692 - val_loss: 0.0051 - val_mae: 0.0533
#
# Epoch 00008: val_loss did not improve from 0.00507
# Epoch 9/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0094 - mae: 0.0699 - val_loss: 0.0033 - val_mae: 0.0441
#
# Epoch 00009: val_loss improved from 0.00507 to 0.00331, saving model to /content/gdrive/My Drive/saved/left_eye_inner_corner/weights/left_eye_inner_corner.ckpt
# Epoch 10/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0076 - mae: 0.0628 - val_loss: 0.0033 - val_mae: 0.0429
#
# Epoch 00010: val_loss did not improve from 0.00331
# Epoch 11/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0070 - mae: 0.0611 - val_loss: 0.0073 - val_mae: 0.0677
#
# Epoch 00011: val_loss did not improve from 0.00331
# Epoch 12/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0090 - mae: 0.0695 - val_loss: 0.0057 - val_mae: 0.0586
#
# Epoch 00012: val_loss did not improve from 0.00331
# Epoch 13/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0081 - mae: 0.0654 - val_loss: 0.0047 - val_mae: 0.0512
#
# Epoch 00013: val_loss did not improve from 0.00331
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 14/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0064 - mae: 0.0575 - val_loss: 0.0025 - val_mae: 0.0335
#
# Epoch 00014: val_loss improved from 0.00331 to 0.00252, saving model to /content/gdrive/My Drive/saved/left_eye_inner_corner/weights/left_eye_inner_corner.ckpt
# Epoch 15/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0061 - mae: 0.0544 - val_loss: 0.0041 - val_mae: 0.0470
#
# Epoch 00015: val_loss did not improve from 0.00252
# Epoch 16/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0057 - mae: 0.0533 - val_loss: 0.0029 - val_mae: 0.0392
#
# Epoch 00016: val_loss did not improve from 0.00252
# Epoch 17/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0063 - mae: 0.0529 - val_loss: 0.0038 - val_mae: 0.0428
#
# Epoch 00017: val_loss did not improve from 0.00252
# Epoch 18/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0052 - mae: 0.0522 - val_loss: 0.0027 - val_mae: 0.0348
#
# Epoch 00018: val_loss did not improve from 0.00252
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 19/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0054 - mae: 0.0514 - val_loss: 0.0029 - val_mae: 0.0377
#
# Epoch 00019: val_loss did not improve from 0.00252
# Epoch 20/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0048 - mae: 0.0488 - val_loss: 0.0031 - val_mae: 0.0392
#
# Epoch 00020: val_loss did not improve from 0.00252
# Epoch 21/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0051 - mae: 0.0505 - val_loss: 0.0029 - val_mae: 0.0360
#
# Epoch 00021: val_loss did not improve from 0.00252
# Epoch 22/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0053 - mae: 0.0508 - val_loss: 0.0026 - val_mae: 0.0360
#
# Epoch 00022: val_loss did not improve from 0.00252
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 00022: early stopping

# %%
# Recreat the same structure of the model and load its saved weights then build it by predicting a random input then save the model
from src.train import compile_model
from tensorflow.keras.models import load_model

model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)

model.load_weights(config.WEIGHT_PATH)
model.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
model.save(config.MODEL_PATH)
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/saved/left_eye_inner_corner/model/assets

# %%
# load the model to check it
m = load_model(config.MODEL_PATH, compile=False)
m.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
# Out:
# array([[0.44172066, 0.16272591]], dtype=float32)

# %%
compile_model(m)
m.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0454 - mae: 0.0287
# [0.04441292956471443, 0.02803351730108261]

# %% [markdown]
# #### **Evaluate the model**

# %%
my_model.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0017 - mae: 0.0269
# [0.0016914403531700373, 0.026892978698015213]

# %%
# Retrieve a list of list results on training and test data sets for each training epoch
loss     = history.history['loss']
val_loss = history.history['val_loss']
epochs   = range(len(loss))
# Plot training and validation loss per epoch
plt.plot(epochs,loss, color='red' , label='training loss')
plt.plot(epochs, val_loss, label='validation loss')
plt.legend()
plt.title ('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
test_generator_with_augmentation =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

# %%
batch = test_generator_with_augmentation.__getitem__(1)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_augmented_results.png", "augmented")

# %%
batch = test_generator.__getitem__(1)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_normal_results.png", "normal")
