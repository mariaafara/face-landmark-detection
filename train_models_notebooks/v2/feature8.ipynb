# %%
feature_index = 8

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
cd gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !rm -rf face-landmark-detection
# !git clone --branch part2 https://github.com/mariaafara/face-landmark-detection.git
# Out:
# Cloning into 'face-landmark-detection'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 203 (delta 79), reused 166 (delta 43), pack-reused 0
# Receiving objects: 100% (203/203), 4.95 MiB | 18.65 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
cd face-landmark-detection/
# Out:
# /content/gdrive/MyDrive/face-landmark-detection

# %%
import os
os.environ['KAGGLE_USERNAME'] = "mariaafara" # username from the json file
os.environ['KAGGLE_KEY'] = "" # key from the json file
# Crearting a Client to host the Kaggle API
# !pip install -q kaggle
# !kaggle datasets download mariaafara/Facial-Landmarks
# !unzip Facial-Landmarks.zip # -d facial-keypoints-detection
# Out:
# Downloading Facial-Landmarks.zip to /content/gdrive/MyDrive/face-landmark-detection
#  96% 135M/141M [00:01<00:00, 86.6MB/s]
# 100% 141M/141M [00:01<00:00, 108MB/s]
# Archive:  Facial-Landmarks.zip
#   inflating: dic_missing_data.pkl
#   inflating: dic_train_data.pkl

# %%
ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
# %ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
from src.utils import *
dic_non_missing_data = load_from_pickle("dic_train_data.pkl")
features = list(dic_non_missing_data.keys())
feature_name = features[feature_index]
os.environ["EPOCHS"] = "100"
os.environ["RGB_CHANNELS"] = "false"
os.environ["PATIENCE_EARLY_STOPPING"] = "8"
# os.environ["PATIENCE_LR"] = "5"
path = F"/content/gdrive/My Drive/saved/"
os.environ["TRAIN_SCALER_PATH"] = "{}_scaler.pkl".format(path+feature_name)
os.environ["WEIGHT_PATH"] = "{}/weights/{}.ckpt".format(path+feature_name, feature_name)
os.environ["FEATURES_DIMENSIONS"] = "2"
os.environ["MODEL_PATH"] = "{}/model".format(path+feature_name)

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from src.config import prediction_model_config as config
from src.model.simple_model import MySimpleModel
from src.train import fit_model, compile_model
from src.data_preparation import DataGenerator
from IPython.display import clear_output
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# !pip install jedi==0.17.2

# %%
dic_non_missing_data[feature_name].head()
# Out:
#    right_eyebrow_inner_end_x  ...                                              Image
# 0                  40.227609  ...  [[238, 236, 237, 238, 240, 240, 239, 241, 241,...
# 1                  42.728851  ...  [[219, 215, 204, 196, 204, 211, 212, 200, 180,...
# 2                  42.193895  ...  [[144, 142, 159, 180, 188, 188, 184, 180, 167,...
# 3                  41.671513  ...  [[193, 192, 193, 194, 194, 194, 193, 192, 168,...
# 4                  38.035436  ...  [[147, 148, 160, 196, 215, 214, 216, 217, 219,...
#
# [5 rows x 3 columns]

# %%
df = dic_non_missing_data[feature_name]
df_train, df_test_val = split_data(df, test_size=0.3)
df_val, df_test = split_data(df_test_val, test_size=0.1)
print(df.shape, df_train.shape, df_val.shape, df_test.shape)

# fit the MinMaxScaler using the training data and then apply the scaler on the testing data before the prediction.
scaler = create_scaler(df_train.iloc[:,:-1])
save_to_pickle(scaler, config.TRAIN_SCALER_PATH)

train_generator = DataGenerator(df_train, 
                                batch_size=config.BATCH_SIZE,
                                augment= config.AUGMENT_TRAIN,
                                rgb_channels= config.RGB_CHANNELS,
                                normalize_image=config.NORMALIZE_IMAGE,
                                normalize_coordinates=config.NORMALIZE_COORDINATES, 
                                scaler=scaler)

val_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

test_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_VAL,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)
# Out:
# (2270, 3) (1589, 3) (612, 3) (69, 3)

# %%
my_model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)
compile_model(my_model, optimizer="adam", loss='mean_squared_error', metrics=['mae'])
my_model, history = fit_model(my_model, config.EPOCHS, train_generator, val_generator, config.WEIGHT_PATH)
# Out:
# Epoch 1/100
# 49/49 [==============================] - 6s 64ms/step - loss: 0.0611 - mae: 0.1921 - val_loss: 0.0115 - val_mae: 0.0866
#
# Epoch 00001: val_loss improved from inf to 0.01146, saving model to /content/gdrive/My Drive/saved/right_eyebrow_inner_end/weights/right_eyebrow_inner_end.ckpt
# Epoch 2/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0156 - mae: 0.0950 - val_loss: 0.0100 - val_mae: 0.0720
#
# Epoch 00002: val_loss improved from 0.01146 to 0.00995, saving model to /content/gdrive/My Drive/saved/right_eyebrow_inner_end/weights/right_eyebrow_inner_end.ckpt
# Epoch 3/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0089 - mae: 0.0716 - val_loss: 0.0080 - val_mae: 0.0693
#
# Epoch 00003: val_loss improved from 0.00995 to 0.00803, saving model to /content/gdrive/My Drive/saved/right_eyebrow_inner_end/weights/right_eyebrow_inner_end.ckpt
# Epoch 4/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0092 - mae: 0.0711 - val_loss: 0.0056 - val_mae: 0.0580
#
# Epoch 00004: val_loss improved from 0.00803 to 0.00561, saving model to /content/gdrive/My Drive/saved/right_eyebrow_inner_end/weights/right_eyebrow_inner_end.ckpt
# Epoch 5/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0084 - mae: 0.0670 - val_loss: 0.0058 - val_mae: 0.0588
#
# Epoch 00005: val_loss did not improve from 0.00561
# Epoch 6/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0076 - mae: 0.0641 - val_loss: 0.0044 - val_mae: 0.0493
#
# Epoch 00006: val_loss improved from 0.00561 to 0.00441, saving model to /content/gdrive/My Drive/saved/right_eyebrow_inner_end/weights/right_eyebrow_inner_end.ckpt
# Epoch 7/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0068 - mae: 0.0605 - val_loss: 0.0062 - val_mae: 0.0586
#
# Epoch 00007: val_loss did not improve from 0.00441
# Epoch 8/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0068 - mae: 0.0614 - val_loss: 0.0055 - val_mae: 0.0566
#
# Epoch 00008: val_loss did not improve from 0.00441
# Epoch 9/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0068 - mae: 0.0619 - val_loss: 0.0060 - val_mae: 0.0554
#
# Epoch 00009: val_loss did not improve from 0.00441
# Epoch 10/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0054 - mae: 0.0540 - val_loss: 0.0059 - val_mae: 0.0550
#
# Epoch 00010: val_loss did not improve from 0.00441
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 11/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0053 - mae: 0.0527 - val_loss: 0.0038 - val_mae: 0.0442
#
# Epoch 00011: val_loss improved from 0.00441 to 0.00377, saving model to /content/gdrive/My Drive/saved/right_eyebrow_inner_end/weights/right_eyebrow_inner_end.ckpt
# Epoch 12/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0045 - mae: 0.0487 - val_loss: 0.0038 - val_mae: 0.0463
#
# Epoch 00012: val_loss did not improve from 0.00377
# Epoch 13/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0045 - mae: 0.0490 - val_loss: 0.0034 - val_mae: 0.0397
#
# Epoch 00013: val_loss improved from 0.00377 to 0.00336, saving model to /content/gdrive/My Drive/saved/right_eyebrow_inner_end/weights/right_eyebrow_inner_end.ckpt
# Epoch 14/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0041 - mae: 0.0471 - val_loss: 0.0035 - val_mae: 0.0440
#
# Epoch 00014: val_loss did not improve from 0.00336
# Epoch 15/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0041 - mae: 0.0470 - val_loss: 0.0032 - val_mae: 0.0413
#
# Epoch 00015: val_loss improved from 0.00336 to 0.00318, saving model to /content/gdrive/My Drive/saved/right_eyebrow_inner_end/weights/right_eyebrow_inner_end.ckpt
# Epoch 16/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0045 - mae: 0.0476 - val_loss: 0.0041 - val_mae: 0.0461
#
# Epoch 00016: val_loss did not improve from 0.00318
# Epoch 17/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0045 - mae: 0.0468 - val_loss: 0.0034 - val_mae: 0.0406
#
# Epoch 00017: val_loss did not improve from 0.00318
# Epoch 18/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0045 - mae: 0.0493 - val_loss: 0.0034 - val_mae: 0.0409
#
# Epoch 00018: val_loss did not improve from 0.00318
# Epoch 19/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0048 - mae: 0.0487 - val_loss: 0.0030 - val_mae: 0.0370
#
# Epoch 00019: val_loss improved from 0.00318 to 0.00299, saving model to /content/gdrive/My Drive/saved/right_eyebrow_inner_end/weights/right_eyebrow_inner_end.ckpt
# Epoch 20/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0042 - mae: 0.0469 - val_loss: 0.0038 - val_mae: 0.0450
#
# Epoch 00020: val_loss did not improve from 0.00299
# Epoch 21/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0043 - mae: 0.0469 - val_loss: 0.0033 - val_mae: 0.0369
#
# Epoch 00021: val_loss did not improve from 0.00299
# Epoch 22/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0034 - val_mae: 0.0396
#
# Epoch 00022: val_loss did not improve from 0.00299
# Epoch 23/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0040 - mae: 0.0471 - val_loss: 0.0031 - val_mae: 0.0419
#
# Epoch 00023: val_loss did not improve from 0.00299
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 24/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0041 - mae: 0.0457 - val_loss: 0.0037 - val_mae: 0.0419
#
# Epoch 00024: val_loss did not improve from 0.00299
# Epoch 25/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0049 - mae: 0.0462 - val_loss: 0.0024 - val_mae: 0.0341
#
# Epoch 00025: val_loss improved from 0.00299 to 0.00239, saving model to /content/gdrive/My Drive/saved/right_eyebrow_inner_end/weights/right_eyebrow_inner_end.ckpt
# Epoch 26/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0042 - mae: 0.0448 - val_loss: 0.0041 - val_mae: 0.0425
#
# Epoch 00026: val_loss did not improve from 0.00239
# Epoch 27/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0035 - mae: 0.0422 - val_loss: 0.0031 - val_mae: 0.0400
#
# Epoch 00027: val_loss did not improve from 0.00239
# Epoch 28/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0038 - mae: 0.0434 - val_loss: 0.0033 - val_mae: 0.0406
#
# Epoch 00028: val_loss did not improve from 0.00239
# Epoch 29/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0035 - mae: 0.0432 - val_loss: 0.0027 - val_mae: 0.0382
#
# Epoch 00029: val_loss did not improve from 0.00239
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 30/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0038 - mae: 0.0448 - val_loss: 0.0026 - val_mae: 0.0360
#
# Epoch 00030: val_loss did not improve from 0.00239
# Epoch 31/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0038 - mae: 0.0447 - val_loss: 0.0031 - val_mae: 0.0364
#
# Epoch 00031: val_loss did not improve from 0.00239
# Epoch 32/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0036 - mae: 0.0435 - val_loss: 0.0036 - val_mae: 0.0393
#
# Epoch 00032: val_loss did not improve from 0.00239
# Epoch 33/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0035 - mae: 0.0428 - val_loss: 0.0033 - val_mae: 0.0380
#
# Epoch 00033: val_loss did not improve from 0.00239
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 00033: early stopping

# %%
# Recreat the same structure of the model and load its saved weights then build it by predicting a random input then save the model
from src.train import compile_model
from tensorflow.keras.models import load_model

model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)

model.load_weights(config.WEIGHT_PATH)
model.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
model.save(config.MODEL_PATH)
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/saved/right_eyebrow_inner_end/model/assets

# %%
# load the model to check it
m = load_model(config.MODEL_PATH, compile=False)
m.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
# Out:
# array([[0.28260928, 0.3068834 ]], dtype=float32)

# %%
compile_model(m)
m.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0487 - mae: 0.0311
# [0.048875629901885986, 0.03089974820613861]

# %% [markdown]
# #### **Evaluate the model**

# %%
my_model.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0023 - mae: 0.0309
# [0.0022581431549042463, 0.030902866274118423]

# %%
# Retrieve a list of list results on training and test data sets for each training epoch
loss     = history.history['loss']
val_loss = history.history['val_loss']
epochs   = range(len(loss))
# Plot training and validation loss per epoch
plt.plot(epochs,loss, color='red' , label='training loss')
plt.plot(epochs, val_loss, label='validation loss')
plt.legend()
plt.title ('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
test_generator_with_augmentation =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

# %%
batch = test_generator_with_augmentation.__getitem__(0)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_augmented_results.png", "augmented")

# %%
batch = test_generator.__getitem__(0)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_normal_results.png", "normal")
