# %%
feature_index = 12

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
cd gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !rm -rf face-landmark-detection
# !git clone --branch part2 https://github.com/mariaafara/face-landmark-detection.git
# Out:
# Cloning into 'face-landmark-detection'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 203 (delta 79), reused 166 (delta 43), pack-reused 0
# Receiving objects: 100% (203/203), 4.95 MiB | 18.86 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
cd face-landmark-detection/
# Out:
# /content/gdrive/MyDrive/face-landmark-detection

# %%
import os
os.environ['KAGGLE_USERNAME'] = "mariaafara" # username from the json file
os.environ['KAGGLE_KEY'] = "" # key from the json file
# Crearting a Client to host the Kaggle API
# !pip install -q kaggle
# !kaggle datasets download mariaafara/Facial-Landmarks
# !unzip Facial-Landmarks.zip # -d facial-keypoints-detection
# Out:
# Downloading Facial-Landmarks.zip to /content/gdrive/MyDrive/face-landmark-detection
#  92% 129M/141M [00:01<00:00, 48.7MB/s]
# 100% 141M/141M [00:01<00:00, 81.1MB/s]
# Archive:  Facial-Landmarks.zip
#   inflating: dic_missing_data.pkl
#   inflating: dic_train_data.pkl

# %%
ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
# %ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
from src.utils import *
dic_non_missing_data = load_from_pickle("dic_train_data.pkl")
features = list(dic_non_missing_data.keys())
feature_name = features[feature_index]
os.environ["EPOCHS"] = "100"
os.environ["RGB_CHANNELS"] = "false"
os.environ["PATIENCE_EARLY_STOPPING"] = "8"
# os.environ["PATIENCE_LR"] = "5"
path = F"/content/gdrive/My Drive/saved/"
os.environ["TRAIN_SCALER_PATH"] = "{}_scaler.pkl".format(path+feature_name)
os.environ["WEIGHT_PATH"] = "{}/weights/{}.ckpt".format(path+feature_name, feature_name)
os.environ["FEATURES_DIMENSIONS"] = "2"
os.environ["MODEL_PATH"] = "{}/model".format(path+feature_name)

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from src.config import prediction_model_config as config
from src.model.simple_model import MySimpleModel
from src.train import fit_model, compile_model
from src.data_preparation import DataGenerator
from IPython.display import clear_output
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# !pip install jedi==0.17.2

# %%
dic_non_missing_data[feature_name].head()
# Out:
#    mouth_center_top_lip_x  ...                                              Image
# 0               43.312602  ...  [[238, 236, 237, 238, 240, 240, 239, 241, 241,...
# 1               46.684596  ...  [[219, 215, 204, 196, 204, 211, 212, 200, 180,...
# 2               47.274947  ...  [[144, 142, 159, 180, 188, 188, 184, 180, 167,...
# 3               50.303165  ...  [[193, 192, 193, 194, 194, 194, 193, 192, 168,...
# 4               44.962748  ...  [[147, 148, 160, 196, 215, 214, 216, 217, 219,...
#
# [5 rows x 3 columns]

# %%
df = dic_non_missing_data[feature_name]
df_train, df_test_val = split_data(df, test_size=0.3)
df_val, df_test = split_data(df_test_val, test_size=0.1)
print(df.shape, df_train.shape, df_val.shape, df_test.shape)

# fit the MinMaxScaler using the training data and then apply the scaler on the testing data before the prediction.
scaler = create_scaler(df_train.iloc[:,:-1])
save_to_pickle(scaler, config.TRAIN_SCALER_PATH)

train_generator = DataGenerator(df_train, 
                                batch_size=config.BATCH_SIZE,
                                augment= config.AUGMENT_TRAIN,
                                rgb_channels= config.RGB_CHANNELS,
                                normalize_image=config.NORMALIZE_IMAGE,
                                normalize_coordinates=config.NORMALIZE_COORDINATES, 
                                scaler=scaler)

val_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

test_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_VAL,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)
# Out:
# (2275, 3) (1592, 3) (614, 3) (69, 3)

# %%
my_model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)
compile_model(my_model, optimizer="adam", loss='mean_squared_error', metrics=['mae'])
my_model, history = fit_model(my_model, config.EPOCHS, train_generator, val_generator, config.WEIGHT_PATH)
# Out:
# Epoch 1/100
# 49/49 [==============================] - 3s 53ms/step - loss: 0.0850 - mae: 0.2277 - val_loss: 0.0353 - val_mae: 0.1360
#
# Epoch 00001: val_loss improved from inf to 0.03527, saving model to /content/gdrive/My Drive/saved/mouth_center_top_lip/weights/mouth_center_top_lip.ckpt
# Epoch 2/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0341 - mae: 0.1396 - val_loss: 0.0135 - val_mae: 0.0872
#
# Epoch 00002: val_loss improved from 0.03527 to 0.01347, saving model to /content/gdrive/My Drive/saved/mouth_center_top_lip/weights/mouth_center_top_lip.ckpt
# Epoch 3/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0197 - mae: 0.1063 - val_loss: 0.0162 - val_mae: 0.0952
#
# Epoch 00003: val_loss did not improve from 0.01347
# Epoch 4/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0165 - mae: 0.0950 - val_loss: 0.0119 - val_mae: 0.0794
#
# Epoch 00004: val_loss improved from 0.01347 to 0.01191, saving model to /content/gdrive/My Drive/saved/mouth_center_top_lip/weights/mouth_center_top_lip.ckpt
# Epoch 5/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0156 - mae: 0.0929 - val_loss: 0.0126 - val_mae: 0.0804
#
# Epoch 00005: val_loss did not improve from 0.01191
# Epoch 6/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0141 - mae: 0.0882 - val_loss: 0.0102 - val_mae: 0.0769
#
# Epoch 00006: val_loss improved from 0.01191 to 0.01021, saving model to /content/gdrive/My Drive/saved/mouth_center_top_lip/weights/mouth_center_top_lip.ckpt
# Epoch 7/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0118 - mae: 0.0802 - val_loss: 0.0114 - val_mae: 0.0809
#
# Epoch 00007: val_loss did not improve from 0.01021
# Epoch 8/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0124 - mae: 0.0811 - val_loss: 0.0112 - val_mae: 0.0768
#
# Epoch 00008: val_loss did not improve from 0.01021
# Epoch 9/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0118 - mae: 0.0801 - val_loss: 0.0089 - val_mae: 0.0670
#
# Epoch 00009: val_loss improved from 0.01021 to 0.00890, saving model to /content/gdrive/My Drive/saved/mouth_center_top_lip/weights/mouth_center_top_lip.ckpt
# Epoch 10/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0097 - mae: 0.0719 - val_loss: 0.0056 - val_mae: 0.0533
#
# Epoch 00010: val_loss improved from 0.00890 to 0.00555, saving model to /content/gdrive/My Drive/saved/mouth_center_top_lip/weights/mouth_center_top_lip.ckpt
# Epoch 11/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0099 - mae: 0.0728 - val_loss: 0.0080 - val_mae: 0.0648
#
# Epoch 00011: val_loss did not improve from 0.00555
# Epoch 12/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0109 - mae: 0.0755 - val_loss: 0.0066 - val_mae: 0.0636
#
# Epoch 00012: val_loss did not improve from 0.00555
# Epoch 13/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0101 - mae: 0.0724 - val_loss: 0.0098 - val_mae: 0.0720
#
# Epoch 00013: val_loss did not improve from 0.00555
# Epoch 14/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0093 - mae: 0.0700 - val_loss: 0.0098 - val_mae: 0.0669
#
# Epoch 00014: val_loss did not improve from 0.00555
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 15/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0086 - mae: 0.0664 - val_loss: 0.0067 - val_mae: 0.0617
#
# Epoch 00015: val_loss did not improve from 0.00555
# Epoch 16/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0080 - mae: 0.0643 - val_loss: 0.0070 - val_mae: 0.0541
#
# Epoch 00016: val_loss did not improve from 0.00555
# Epoch 17/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0071 - mae: 0.0618 - val_loss: 0.0069 - val_mae: 0.0608
#
# Epoch 00017: val_loss did not improve from 0.00555
# Epoch 18/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0069 - mae: 0.0607 - val_loss: 0.0045 - val_mae: 0.0505
#
# Epoch 00018: val_loss improved from 0.00555 to 0.00450, saving model to /content/gdrive/My Drive/saved/mouth_center_top_lip/weights/mouth_center_top_lip.ckpt
# Epoch 19/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0068 - mae: 0.0609 - val_loss: 0.0050 - val_mae: 0.0480
#
# Epoch 00019: val_loss did not improve from 0.00450
# Epoch 20/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0068 - mae: 0.0595 - val_loss: 0.0083 - val_mae: 0.0650
#
# Epoch 00020: val_loss did not improve from 0.00450
# Epoch 21/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0065 - mae: 0.0579 - val_loss: 0.0040 - val_mae: 0.0472
#
# Epoch 00021: val_loss improved from 0.00450 to 0.00402, saving model to /content/gdrive/My Drive/saved/mouth_center_top_lip/weights/mouth_center_top_lip.ckpt
# Epoch 22/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0067 - mae: 0.0583 - val_loss: 0.0036 - val_mae: 0.0456
#
# Epoch 00022: val_loss improved from 0.00402 to 0.00364, saving model to /content/gdrive/My Drive/saved/mouth_center_top_lip/weights/mouth_center_top_lip.ckpt
# Epoch 23/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0065 - mae: 0.0591 - val_loss: 0.0048 - val_mae: 0.0523
#
# Epoch 00023: val_loss did not improve from 0.00364
# Epoch 24/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0066 - mae: 0.0581 - val_loss: 0.0035 - val_mae: 0.0440
#
# Epoch 00024: val_loss improved from 0.00364 to 0.00352, saving model to /content/gdrive/My Drive/saved/mouth_center_top_lip/weights/mouth_center_top_lip.ckpt
# Epoch 25/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0063 - mae: 0.0585 - val_loss: 0.0047 - val_mae: 0.0482
#
# Epoch 00025: val_loss did not improve from 0.00352
# Epoch 26/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0063 - mae: 0.0568 - val_loss: 0.0056 - val_mae: 0.0498
#
# Epoch 00026: val_loss did not improve from 0.00352
# Epoch 27/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0071 - mae: 0.0600 - val_loss: 0.0040 - val_mae: 0.0448
#
# Epoch 00027: val_loss did not improve from 0.00352
# Epoch 28/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0068 - mae: 0.0585 - val_loss: 0.0042 - val_mae: 0.0482
#
# Epoch 00028: val_loss did not improve from 0.00352
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 29/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0068 - mae: 0.0577 - val_loss: 0.0035 - val_mae: 0.0430
#
# Epoch 00029: val_loss did not improve from 0.00352
# Epoch 30/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0064 - mae: 0.0580 - val_loss: 0.0033 - val_mae: 0.0391
#
# Epoch 00030: val_loss improved from 0.00352 to 0.00333, saving model to /content/gdrive/My Drive/saved/mouth_center_top_lip/weights/mouth_center_top_lip.ckpt
# Epoch 31/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0059 - mae: 0.0555 - val_loss: 0.0036 - val_mae: 0.0453
#
# Epoch 00031: val_loss did not improve from 0.00333
# Epoch 32/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0055 - mae: 0.0540 - val_loss: 0.0032 - val_mae: 0.0418
#
# Epoch 00032: val_loss improved from 0.00333 to 0.00322, saving model to /content/gdrive/My Drive/saved/mouth_center_top_lip/weights/mouth_center_top_lip.ckpt
# Epoch 33/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0059 - mae: 0.0552 - val_loss: 0.0036 - val_mae: 0.0441
#
# Epoch 00033: val_loss did not improve from 0.00322
# Epoch 34/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0055 - mae: 0.0544 - val_loss: 0.0035 - val_mae: 0.0435
#
# Epoch 00034: val_loss did not improve from 0.00322
# Epoch 35/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0057 - mae: 0.0542 - val_loss: 0.0042 - val_mae: 0.0461
#
# Epoch 00035: val_loss did not improve from 0.00322
# Epoch 36/100
# 49/49 [==============================] - 3s 53ms/step - loss: 0.0057 - mae: 0.0546 - val_loss: 0.0035 - val_mae: 0.0442
#
# Epoch 00036: val_loss did not improve from 0.00322
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 37/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0063 - mae: 0.0563 - val_loss: 0.0042 - val_mae: 0.0438
#
# Epoch 00037: val_loss did not improve from 0.00322
# Epoch 38/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0054 - mae: 0.0528 - val_loss: 0.0041 - val_mae: 0.0433
#
# Epoch 00038: val_loss did not improve from 0.00322
# Epoch 39/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0058 - mae: 0.0554 - val_loss: 0.0036 - val_mae: 0.0437
#
# Epoch 00039: val_loss did not improve from 0.00322
# Epoch 40/100
# 49/49 [==============================] - 3s 52ms/step - loss: 0.0058 - mae: 0.0547 - val_loss: 0.0047 - val_mae: 0.0444
#
# Epoch 00040: val_loss did not improve from 0.00322
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 00040: early stopping

# %%
# Recreat the same structure of the model and load its saved weights then build it by predicting a random input then save the model
from src.train import compile_model
from tensorflow.keras.models import load_model

model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)

model.load_weights(config.WEIGHT_PATH)
model.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
model.save(config.MODEL_PATH)
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/saved/mouth_center_top_lip/model/assets

# %%
# load the model to check it
m = load_model(config.MODEL_PATH, compile=False)
m.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
# Out:
# array([[0.67758477, 0.70380586]], dtype=float32)

# %%
compile_model(m)
m.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0478 - mae: 0.0297
# [0.04839903861284256, 0.03010733798146248]

# %% [markdown]
# #### **Evaluate the model**

# %%
my_model.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0018 - mae: 0.0305
# [0.0017990854103118181, 0.030461594462394714]

# %%
# Retrieve a list of list results on training and test data sets for each training epoch
loss     = history.history['loss']
val_loss = history.history['val_loss']
epochs   = range(len(loss))
# Plot training and validation loss per epoch
plt.plot(epochs,loss, color='red' , label='training loss')
plt.plot(epochs, val_loss, label='validation loss')
plt.legend()
plt.title ('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
test_generator_with_augmentation =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

# %%
batch = test_generator_with_augmentation.__getitem__(0)
visualize_random_predicted_images(m, batch, scaler, feature_name, path+feature_name+"_augmented_results.png", "augmented")

# %%
batch = test_generator.__getitem__(0)
visualize_random_predicted_images(m, batch, scaler, feature_name, path+feature_name+"_normal_results.png", "normal")
