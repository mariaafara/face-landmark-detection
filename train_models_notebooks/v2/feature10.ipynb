# %%
feature_index = 10

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
cd gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !rm -rf face-landmark-detection
# !git clone --branch part2 https://github.com/mariaafara/face-landmark-detection.git
# Out:
# Cloning into 'face-landmark-detection'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 203 (delta 79), reused 166 (delta 43), pack-reused 0
# Receiving objects: 100% (203/203), 4.95 MiB | 18.58 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
cd face-landmark-detection/
# Out:
# /content/gdrive/MyDrive/face-landmark-detection

# %%
import os
os.environ['KAGGLE_USERNAME'] = "mariaafara" # username from the json file
os.environ['KAGGLE_KEY'] = "" # key from the json file
# Crearting a Client to host the Kaggle API
# !pip install -q kaggle
# !kaggle datasets download mariaafara/Facial-Landmarks
# !unzip Facial-Landmarks.zip # -d facial-keypoints-detection
# Out:
# Downloading Facial-Landmarks.zip to /content/gdrive/MyDrive/face-landmark-detection
#  92% 129M/141M [00:01<00:00, 87.7MB/s]
# 100% 141M/141M [00:01<00:00, 112MB/s]
# Archive:  Facial-Landmarks.zip
#   inflating: dic_missing_data.pkl
#   inflating: dic_train_data.pkl

# %%
ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
# %ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
from src.utils import *
dic_non_missing_data = load_from_pickle("dic_train_data.pkl")
features = list(dic_non_missing_data.keys())
feature_name = features[feature_index]
os.environ["EPOCHS"] = "100"
os.environ["RGB_CHANNELS"] = "false"
os.environ["PATIENCE_EARLY_STOPPING"] = "8"
# os.environ["PATIENCE_LR"] = "5"
path = F"/content/gdrive/My Drive/saved/"
os.environ["TRAIN_SCALER_PATH"] = "{}_scaler.pkl".format(path+feature_name)
os.environ["WEIGHT_PATH"] = "{}/weights/{}.ckpt".format(path+feature_name, feature_name)
os.environ["FEATURES_DIMENSIONS"] = "2"
os.environ["MODEL_PATH"] = "{}/model".format(path+feature_name)

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from src.config import prediction_model_config as config
from src.model.simple_model import MySimpleModel
from src.train import fit_model, compile_model
from src.data_preparation import DataGenerator
from IPython.display import clear_output
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# !pip install jedi==0.17.2

# %%
dic_non_missing_data[feature_name].head()
# Out:
#    mouth_left_corner_x  ...                                              Image
# 0            61.195308  ...  [[238, 236, 237, 238, 240, 240, 239, 241, 241,...
# 1            56.421447  ...  [[219, 215, 204, 196, 204, 211, 212, 200, 180,...
# 2            60.822947  ...  [[144, 142, 159, 180, 188, 188, 184, 180, 167,...
# 3            65.598887  ...  [[193, 192, 193, 194, 194, 194, 193, 192, 168,...
# 4            60.671411  ...  [[147, 148, 160, 196, 215, 214, 216, 217, 219,...
#
# [5 rows x 3 columns]

# %%
df = dic_non_missing_data[feature_name]
df_train, df_test_val = split_data(df, test_size=0.3)
df_val, df_test = split_data(df_test_val, test_size=0.1)
print(df.shape, df_train.shape, df_val.shape, df_test.shape)

# fit the MinMaxScaler using the training data and then apply the scaler on the testing data before the prediction.
scaler = create_scaler(df_train.iloc[:,:-1])
save_to_pickle(scaler, config.TRAIN_SCALER_PATH)

train_generator = DataGenerator(df_train, 
                                batch_size=config.BATCH_SIZE,
                                augment= config.AUGMENT_TRAIN,
                                rgb_channels= config.RGB_CHANNELS,
                                normalize_image=config.NORMALIZE_IMAGE,
                                normalize_coordinates=config.NORMALIZE_COORDINATES, 
                                scaler=scaler)

val_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

test_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_VAL,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)
# Out:
# (2269, 3) (1588, 3) (612, 3) (69, 3)

# %%
my_model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)
compile_model(my_model, optimizer="adam", loss='mean_squared_error', metrics=['mae'])
my_model, history = fit_model(my_model, config.EPOCHS, train_generator, val_generator, config.WEIGHT_PATH)
# Out:
# Epoch 1/100
# 49/49 [==============================] - 6s 65ms/step - loss: 0.1368 - mae: 0.2914 - val_loss: 0.0233 - val_mae: 0.1164
#
# Epoch 00001: val_loss improved from inf to 0.02333, saving model to /content/gdrive/My Drive/saved/mouth_left_corner/weights/mouth_left_corner.ckpt
# Epoch 2/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0379 - mae: 0.1519 - val_loss: 0.0226 - val_mae: 0.1132
#
# Epoch 00002: val_loss improved from 0.02333 to 0.02255, saving model to /content/gdrive/My Drive/saved/mouth_left_corner/weights/mouth_left_corner.ckpt
# Epoch 3/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0274 - mae: 0.1241 - val_loss: 0.0181 - val_mae: 0.1062
#
# Epoch 00003: val_loss improved from 0.02255 to 0.01813, saving model to /content/gdrive/My Drive/saved/mouth_left_corner/weights/mouth_left_corner.ckpt
# Epoch 4/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0223 - mae: 0.1154 - val_loss: 0.0200 - val_mae: 0.1067
#
# Epoch 00004: val_loss did not improve from 0.01813
# Epoch 5/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0195 - mae: 0.1077 - val_loss: 0.0184 - val_mae: 0.1044
#
# Epoch 00005: val_loss did not improve from 0.01813
# Epoch 6/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0176 - mae: 0.1005 - val_loss: 0.0186 - val_mae: 0.1042
#
# Epoch 00006: val_loss did not improve from 0.01813
# Epoch 7/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0165 - mae: 0.0974 - val_loss: 0.0140 - val_mae: 0.0897
#
# Epoch 00007: val_loss improved from 0.01813 to 0.01400, saving model to /content/gdrive/My Drive/saved/mouth_left_corner/weights/mouth_left_corner.ckpt
# Epoch 8/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0178 - mae: 0.0995 - val_loss: 0.0157 - val_mae: 0.0931
#
# Epoch 00008: val_loss did not improve from 0.01400
# Epoch 9/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0151 - mae: 0.0935 - val_loss: 0.0090 - val_mae: 0.0718
#
# Epoch 00009: val_loss improved from 0.01400 to 0.00896, saving model to /content/gdrive/My Drive/saved/mouth_left_corner/weights/mouth_left_corner.ckpt
# Epoch 10/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0134 - mae: 0.0866 - val_loss: 0.0094 - val_mae: 0.0744
#
# Epoch 00010: val_loss did not improve from 0.00896
# Epoch 11/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0132 - mae: 0.0858 - val_loss: 0.0112 - val_mae: 0.0755
#
# Epoch 00011: val_loss did not improve from 0.00896
# Epoch 12/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0120 - mae: 0.0828 - val_loss: 0.0091 - val_mae: 0.0725
#
# Epoch 00012: val_loss did not improve from 0.00896
# Epoch 13/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0118 - mae: 0.0807 - val_loss: 0.0109 - val_mae: 0.0749
#
# Epoch 00013: val_loss did not improve from 0.00896
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 14/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0116 - mae: 0.0801 - val_loss: 0.0076 - val_mae: 0.0651
#
# Epoch 00014: val_loss improved from 0.00896 to 0.00760, saving model to /content/gdrive/My Drive/saved/mouth_left_corner/weights/mouth_left_corner.ckpt
# Epoch 15/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0096 - mae: 0.0727 - val_loss: 0.0079 - val_mae: 0.0666
#
# Epoch 00015: val_loss did not improve from 0.00760
# Epoch 16/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0102 - mae: 0.0744 - val_loss: 0.0071 - val_mae: 0.0639
#
# Epoch 00016: val_loss improved from 0.00760 to 0.00710, saving model to /content/gdrive/My Drive/saved/mouth_left_corner/weights/mouth_left_corner.ckpt
# Epoch 17/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0109 - mae: 0.0761 - val_loss: 0.0073 - val_mae: 0.0649
#
# Epoch 00017: val_loss did not improve from 0.00710
# Epoch 18/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0098 - mae: 0.0736 - val_loss: 0.0064 - val_mae: 0.0607
#
# Epoch 00018: val_loss improved from 0.00710 to 0.00640, saving model to /content/gdrive/My Drive/saved/mouth_left_corner/weights/mouth_left_corner.ckpt
# Epoch 19/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0103 - mae: 0.0742 - val_loss: 0.0068 - val_mae: 0.0634
#
# Epoch 00019: val_loss did not improve from 0.00640
# Epoch 20/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0097 - mae: 0.0718 - val_loss: 0.0087 - val_mae: 0.0709
#
# Epoch 00020: val_loss did not improve from 0.00640
# Epoch 21/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0093 - mae: 0.0722 - val_loss: 0.0067 - val_mae: 0.0647
#
# Epoch 00021: val_loss did not improve from 0.00640
# Epoch 22/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0096 - mae: 0.0726 - val_loss: 0.0070 - val_mae: 0.0642
#
# Epoch 00022: val_loss did not improve from 0.00640
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 23/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0100 - mae: 0.0735 - val_loss: 0.0081 - val_mae: 0.0658
#
# Epoch 00023: val_loss did not improve from 0.00640
# Epoch 24/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0093 - mae: 0.0713 - val_loss: 0.0065 - val_mae: 0.0599
#
# Epoch 00024: val_loss did not improve from 0.00640
# Epoch 25/100
# 49/49 [==============================] - 2s 50ms/step - loss: 0.0087 - mae: 0.0688 - val_loss: 0.0063 - val_mae: 0.0589
#
# Epoch 00025: val_loss improved from 0.00640 to 0.00629, saving model to /content/gdrive/My Drive/saved/mouth_left_corner/weights/mouth_left_corner.ckpt
# Epoch 26/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0089 - mae: 0.0688 - val_loss: 0.0067 - val_mae: 0.0572
#
# Epoch 00026: val_loss did not improve from 0.00629
# Epoch 27/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0088 - mae: 0.0686 - val_loss: 0.0073 - val_mae: 0.0609
#
# Epoch 00027: val_loss did not improve from 0.00629
# Epoch 28/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0080 - mae: 0.0667 - val_loss: 0.0090 - val_mae: 0.0676
#
# Epoch 00028: val_loss did not improve from 0.00629
# Epoch 29/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0083 - mae: 0.0677 - val_loss: 0.0076 - val_mae: 0.0620
#
# Epoch 00029: val_loss did not improve from 0.00629
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 30/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0085 - mae: 0.0676 - val_loss: 0.0057 - val_mae: 0.0555
#
# Epoch 00030: val_loss improved from 0.00629 to 0.00572, saving model to /content/gdrive/My Drive/saved/mouth_left_corner/weights/mouth_left_corner.ckpt
# Epoch 31/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0079 - mae: 0.0654 - val_loss: 0.0077 - val_mae: 0.0623
#
# Epoch 00031: val_loss did not improve from 0.00572
# Epoch 32/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0090 - mae: 0.0704 - val_loss: 0.0064 - val_mae: 0.0597
#
# Epoch 00032: val_loss did not improve from 0.00572
# Epoch 33/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0094 - mae: 0.0713 - val_loss: 0.0072 - val_mae: 0.0642
#
# Epoch 00033: val_loss did not improve from 0.00572
# Epoch 34/100
# 49/49 [==============================] - 3s 51ms/step - loss: 0.0089 - mae: 0.0678 - val_loss: 0.0070 - val_mae: 0.0650
#
# Epoch 00034: val_loss did not improve from 0.00572
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 35/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0082 - mae: 0.0665 - val_loss: 0.0084 - val_mae: 0.0620
#
# Epoch 00035: val_loss did not improve from 0.00572
# Epoch 36/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0089 - mae: 0.0695 - val_loss: 0.0078 - val_mae: 0.0592
#
# Epoch 00036: val_loss did not improve from 0.00572
# Epoch 37/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0090 - mae: 0.0686 - val_loss: 0.0050 - val_mae: 0.0532
#
# Epoch 00037: val_loss improved from 0.00572 to 0.00496, saving model to /content/gdrive/My Drive/saved/mouth_left_corner/weights/mouth_left_corner.ckpt
# Epoch 38/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0090 - mae: 0.0690 - val_loss: 0.0095 - val_mae: 0.0631
#
# Epoch 00038: val_loss did not improve from 0.00496
# Epoch 39/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0087 - mae: 0.0680 - val_loss: 0.0070 - val_mae: 0.0599
#
# Epoch 00039: val_loss did not improve from 0.00496
# Epoch 40/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0082 - mae: 0.0672 - val_loss: 0.0063 - val_mae: 0.0583
#
# Epoch 00040: val_loss did not improve from 0.00496
# Epoch 41/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0089 - mae: 0.0701 - val_loss: 0.0065 - val_mae: 0.0620
#
# Epoch 00041: val_loss did not improve from 0.00496
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 42/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0086 - mae: 0.0674 - val_loss: 0.0072 - val_mae: 0.0666
#
# Epoch 00042: val_loss did not improve from 0.00496
# Epoch 43/100
# 49/49 [==============================] - 3s 51ms/step - loss: 0.0083 - mae: 0.0664 - val_loss: 0.0079 - val_mae: 0.0637
#
# Epoch 00043: val_loss did not improve from 0.00496
# Epoch 44/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0091 - mae: 0.0697 - val_loss: 0.0060 - val_mae: 0.0563
#
# Epoch 00044: val_loss did not improve from 0.00496
# Epoch 45/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0088 - mae: 0.0687 - val_loss: 0.0056 - val_mae: 0.0526
#
# Epoch 00045: val_loss did not improve from 0.00496
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 00045: early stopping

# %%
# Recreat the same structure of the model and load its saved weights then build it by predicting a random input then save the model
from src.train import compile_model
from tensorflow.keras.models import load_model

model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)

model.load_weights(config.WEIGHT_PATH)
model.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
model.save(config.MODEL_PATH)
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/saved/mouth_left_corner/model/assets

# %%
# load the model to check it
m = load_model(config.MODEL_PATH, compile=False)
m.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
# Out:
# array([[1.175567  , 0.39022592]], dtype=float32)

# %%
compile_model(m)
m.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0750 - mae: 0.0467
# [0.07572505623102188, 0.047144804149866104]

# %% [markdown]
# #### **Evaluate the model**

# %%
my_model.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0041 - mae: 0.0472
# [0.004061228130012751, 0.04720594733953476]

# %%
# Retrieve a list of list results on training and test data sets for each training epoch
loss     = history.history['loss']
val_loss = history.history['val_loss']
epochs   = range(len(loss))
# Plot training and validation loss per epoch
plt.plot(epochs,loss, color='red' , label='training loss')
plt.plot(epochs, val_loss, label='validation loss')
plt.legend()
plt.title ('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
test_generator_with_augmentation =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

# %%
batch = test_generator_with_augmentation.__getitem__(0)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_augmented_results.png", "augmented")

# %%
batch = test_generator.__getitem__(0)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_normal_results.png", "normal")
