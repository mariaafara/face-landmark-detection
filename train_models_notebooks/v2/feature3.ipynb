# %%
feature_index = 3

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
cd gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !rm -rf face-landmark-detection
# !git clone --branch part2 https://github.com/mariaafara/face-landmark-detection.git
# Out:
# Cloning into 'face-landmark-detection'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 203 (delta 79), reused 166 (delta 43), pack-reused 0
# Receiving objects: 100% (203/203), 4.95 MiB | 19.29 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
cd face-landmark-detection/
# Out:
# /content/gdrive/MyDrive/face-landmark-detection

# %%
import os
os.environ['KAGGLE_USERNAME'] = "mariaafara" # username from the json file
os.environ['KAGGLE_KEY'] = "" # key from the json file
# Crearting a Client to host the Kaggle API
# !pip install -q kaggle
# !kaggle datasets download mariaafara/Facial-Landmarks
# !unzip Facial-Landmarks.zip # -d facial-keypoints-detection
# Out:
# Downloading Facial-Landmarks.zip to /content/gdrive/MyDrive/face-landmark-detection
#  97% 136M/141M [00:01<00:00, 89.6MB/s]
# 100% 141M/141M [00:01<00:00, 115MB/s]
# Archive:  Facial-Landmarks.zip
#   inflating: dic_missing_data.pkl
#   inflating: dic_train_data.pkl

# %%
ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
from src.utils import *
dic_non_missing_data = load_from_pickle("dic_train_data.pkl")
features = list(dic_non_missing_data.keys())
feature_name = features[feature_index]
os.environ["EPOCHS"] = "100"
os.environ["RGB_CHANNELS"] = "false"
os.environ["PATIENCE_EARLY_STOPPING"] = "8"
# os.environ["PATIENCE_LR"] = "5"
path = F"/content/gdrive/My Drive/saved/"
os.environ["TRAIN_SCALER_PATH"] = "{}_scaler.pkl".format(path+feature_name)
os.environ["WEIGHT_PATH"] = "{}/weights/{}.ckpt".format(path+feature_name, feature_name)
os.environ["FEATURES_DIMENSIONS"] = "2"
os.environ["MODEL_PATH"] = "{}/model".format(path+feature_name)

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from src.config import prediction_model_config as config
from src.model.simple_model import MySimpleModel
from src.train import fit_model, compile_model
from src.data_preparation import DataGenerator
from IPython.display import clear_output
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# !pip install jedi==0.17.2

# %%
dic_non_missing_data[feature_name].head()
# Out:
#    left_eye_outer_corner_x  ...                                              Image
# 0                73.130346  ...  [[238, 236, 237, 238, 240, 240, 239, 241, 241,...
# 1                70.722723  ...  [[219, 215, 204, 196, 204, 211, 212, 200, 180,...
# 2                70.984421  ...  [[144, 142, 159, 180, 188, 188, 184, 180, 167,...
# 3                72.314713  ...  [[193, 192, 193, 194, 194, 194, 193, 192, 168,...
# 4                72.515926  ...  [[147, 148, 160, 196, 215, 214, 216, 217, 219,...
#
# [5 rows x 3 columns]

# %%
df = dic_non_missing_data[feature_name]
df_train, df_test_val = split_data(df, test_size=0.3)
df_val, df_test = split_data(df_test_val, test_size=0.1)
print(df.shape, df_train.shape, df_val.shape, df_test.shape)

# fit the MinMaxScaler using the training data and then apply the scaler on the testing data before the prediction.
scaler = create_scaler(df_train.iloc[:,:-1])
save_to_pickle(scaler, config.TRAIN_SCALER_PATH)

train_generator = DataGenerator(df_train, 
                                batch_size=config.BATCH_SIZE,
                                augment= config.AUGMENT_TRAIN,
                                rgb_channels= config.RGB_CHANNELS,
                                normalize_image=config.NORMALIZE_IMAGE,
                                normalize_coordinates=config.NORMALIZE_COORDINATES, 
                                scaler=scaler)

val_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

test_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_VAL,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)
# Out:
# (2267, 3) (1586, 3) (612, 3) (69, 3)

# %%
my_model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)
compile_model(my_model, optimizer="adam", loss='mean_squared_error', metrics=['mae'])
my_model, history = fit_model(my_model, config.EPOCHS, train_generator, val_generator, config.WEIGHT_PATH)
# Out:
# Epoch 1/100
# 49/49 [==============================] - 6s 65ms/step - loss: 0.1220 - mae: 0.2694 - val_loss: 0.0430 - val_mae: 0.1452
#
# Epoch 00001: val_loss improved from inf to 0.04303, saving model to /content/gdrive/My Drive/saved/left_eye_outer_corner/weights/left_eye_outer_corner.ckpt
# Epoch 2/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0246 - mae: 0.1213 - val_loss: 0.0232 - val_mae: 0.0980
#
# Epoch 00002: val_loss improved from 0.04303 to 0.02325, saving model to /content/gdrive/My Drive/saved/left_eye_outer_corner/weights/left_eye_outer_corner.ckpt
# Epoch 3/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0174 - mae: 0.0994 - val_loss: 0.0205 - val_mae: 0.0876
#
# Epoch 00003: val_loss improved from 0.02325 to 0.02054, saving model to /content/gdrive/My Drive/saved/left_eye_outer_corner/weights/left_eye_outer_corner.ckpt
# Epoch 4/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0174 - mae: 0.0990 - val_loss: 0.0216 - val_mae: 0.0950
#
# Epoch 00004: val_loss did not improve from 0.02054
# Epoch 5/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0148 - mae: 0.0905 - val_loss: 0.0212 - val_mae: 0.0871
#
# Epoch 00005: val_loss did not improve from 0.02054
# Epoch 6/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0118 - mae: 0.0824 - val_loss: 0.0183 - val_mae: 0.0785
#
# Epoch 00006: val_loss improved from 0.02054 to 0.01827, saving model to /content/gdrive/My Drive/saved/left_eye_outer_corner/weights/left_eye_outer_corner.ckpt
# Epoch 7/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0141 - mae: 0.0869 - val_loss: 0.0167 - val_mae: 0.0765
#
# Epoch 00007: val_loss improved from 0.01827 to 0.01674, saving model to /content/gdrive/My Drive/saved/left_eye_outer_corner/weights/left_eye_outer_corner.ckpt
# Epoch 8/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0110 - mae: 0.0781 - val_loss: 0.0152 - val_mae: 0.0686
#
# Epoch 00008: val_loss improved from 0.01674 to 0.01521, saving model to /content/gdrive/My Drive/saved/left_eye_outer_corner/weights/left_eye_outer_corner.ckpt
# Epoch 9/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0108 - mae: 0.0760 - val_loss: 0.0207 - val_mae: 0.0805
#
# Epoch 00009: val_loss did not improve from 0.01521
# Epoch 10/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0107 - mae: 0.0760 - val_loss: 0.0157 - val_mae: 0.0713
#
# Epoch 00010: val_loss did not improve from 0.01521
# Epoch 11/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0101 - mae: 0.0738 - val_loss: 0.0172 - val_mae: 0.0773
#
# Epoch 00011: val_loss did not improve from 0.01521
# Epoch 12/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0094 - mae: 0.0706 - val_loss: 0.0165 - val_mae: 0.0717
#
# Epoch 00012: val_loss did not improve from 0.01521
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 13/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0093 - mae: 0.0670 - val_loss: 0.0151 - val_mae: 0.0623
#
# Epoch 00013: val_loss improved from 0.01521 to 0.01513, saving model to /content/gdrive/My Drive/saved/left_eye_outer_corner/weights/left_eye_outer_corner.ckpt
# Epoch 14/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0074 - mae: 0.0621 - val_loss: 0.0136 - val_mae: 0.0592
#
# Epoch 00014: val_loss improved from 0.01513 to 0.01355, saving model to /content/gdrive/My Drive/saved/left_eye_outer_corner/weights/left_eye_outer_corner.ckpt
# Epoch 15/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0072 - mae: 0.0619 - val_loss: 0.0144 - val_mae: 0.0618
#
# Epoch 00015: val_loss did not improve from 0.01355
# Epoch 16/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0071 - mae: 0.0614 - val_loss: 0.0137 - val_mae: 0.0597
#
# Epoch 00016: val_loss did not improve from 0.01355
# Epoch 17/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0072 - mae: 0.0615 - val_loss: 0.0136 - val_mae: 0.0575
#
# Epoch 00017: val_loss did not improve from 0.01355
# Epoch 18/100
# 49/49 [==============================] - 2s 44ms/step - loss: 0.0070 - mae: 0.0599 - val_loss: 0.0184 - val_mae: 0.0771
#
# Epoch 00018: val_loss did not improve from 0.01355
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 19/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0070 - mae: 0.0596 - val_loss: 0.0130 - val_mae: 0.0591
#
# Epoch 00019: val_loss improved from 0.01355 to 0.01305, saving model to /content/gdrive/My Drive/saved/left_eye_outer_corner/weights/left_eye_outer_corner.ckpt
# Epoch 20/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0067 - mae: 0.0588 - val_loss: 0.0126 - val_mae: 0.0630
#
# Epoch 00020: val_loss improved from 0.01305 to 0.01264, saving model to /content/gdrive/My Drive/saved/left_eye_outer_corner/weights/left_eye_outer_corner.ckpt
# Epoch 21/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0070 - mae: 0.0594 - val_loss: 0.0138 - val_mae: 0.0563
#
# Epoch 00021: val_loss did not improve from 0.01264
# Epoch 22/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0065 - mae: 0.0574 - val_loss: 0.0145 - val_mae: 0.0634
#
# Epoch 00022: val_loss did not improve from 0.01264
# Epoch 23/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0062 - mae: 0.0564 - val_loss: 0.0153 - val_mae: 0.0626
#
# Epoch 00023: val_loss did not improve from 0.01264
# Epoch 24/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0062 - mae: 0.0566 - val_loss: 0.0139 - val_mae: 0.0579
#
# Epoch 00024: val_loss did not improve from 0.01264
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 25/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0064 - mae: 0.0575 - val_loss: 0.0136 - val_mae: 0.0552
#
# Epoch 00025: val_loss did not improve from 0.01264
# Epoch 26/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0059 - mae: 0.0556 - val_loss: 0.0147 - val_mae: 0.0604
#
# Epoch 00026: val_loss did not improve from 0.01264
# Epoch 27/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0060 - mae: 0.0564 - val_loss: 0.0147 - val_mae: 0.0627
#
# Epoch 00027: val_loss did not improve from 0.01264
# Epoch 28/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0057 - mae: 0.0563 - val_loss: 0.0141 - val_mae: 0.0645
#
# Epoch 00028: val_loss did not improve from 0.01264
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 00028: early stopping

# %%
# Recreat the same structure of the model and load its saved weights then build it by predicting a random input then save the model
from src.train import compile_model
from tensorflow.keras.models import load_model

model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)

model.load_weights(config.WEIGHT_PATH)
model.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
model.save(config.MODEL_PATH)
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/saved/left_eye_outer_corner/model/assets

# %%
# load the model to check it
m = load_model(config.MODEL_PATH, compile=False)
m.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
# Out:
# array([[ 0.8605594 , -0.02932539]], dtype=float32)

# %%
compile_model(m)
m.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0688 - mae: 0.0431
# [0.07555738091468811, 0.04742295295000076]

# %% [markdown]
# #### **Evaluate the model**

# %%
my_model.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0122 - mae: 0.0451
# [0.012205813080072403, 0.04508962482213974]

# %%
# Retrieve a list of list results on training and test data sets for each training epoch
loss     = history.history['loss']
val_loss = history.history['val_loss']
epochs   = range(len(loss))
# Plot training and validation loss per epoch
plt.plot(epochs,loss, color='red' , label='training loss')
plt.plot(epochs, val_loss, label='validation loss')
plt.legend()
plt.title ('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
test_generator_with_augmentation =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

# %%
batch = test_generator_with_augmentation.__getitem__(1)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_augmented_results.png", "augmented")

# %%
batch = test_generator.__getitem__(1)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_normal_results.png", "normal")
