# %%
feature_index = 11

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
cd gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !rm -rf face-landmark-detection
# !git clone --branch part2 https://github.com/mariaafara/face-landmark-detection.git
# Out:
# Cloning into 'face-landmark-detection'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 203 (delta 79), reused 166 (delta 43), pack-reused 0
# Receiving objects: 100% (203/203), 4.95 MiB | 18.45 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
cd face-landmark-detection/
# Out:
# /content/gdrive/MyDrive/face-landmark-detection

# %%
import os
os.environ['KAGGLE_USERNAME'] = "mariaafara" # username from the json file
os.environ['KAGGLE_KEY'] = "" # key from the json file
# Crearting a Client to host the Kaggle API
# !pip install -q kaggle
# !kaggle datasets download mariaafara/Facial-Landmarks
# !unzip Facial-Landmarks.zip # -d facial-keypoints-detection
# Out:
# Downloading Facial-Landmarks.zip to /content/gdrive/My Drive/face-landmark-detection
#  96% 135M/141M [00:01<00:00, 110MB/s]
# 100% 141M/141M [00:01<00:00, 126MB/s]
# Archive:  Facial-Landmarks.zip
#   inflating: dic_missing_data.pkl
#   inflating: dic_train_data.pkl

# %%
ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
# %ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
from src.utils import *
dic_non_missing_data = load_from_pickle("dic_train_data.pkl")
features = list(dic_non_missing_data.keys())
feature_name = features[feature_index]
os.environ["EPOCHS"] = "100"
os.environ["RGB_CHANNELS"] = "false"
os.environ["PATIENCE_EARLY_STOPPING"] = "8"
# os.environ["PATIENCE_LR"] = "5"
path = F"/content/gdrive/My Drive/saved/"
os.environ["TRAIN_SCALER_PATH"] = "{}_scaler.pkl".format(path+feature_name)
os.environ["WEIGHT_PATH"] = "{}/weights/{}.ckpt".format(path+feature_name, feature_name)
os.environ["FEATURES_DIMENSIONS"] = "2"
os.environ["MODEL_PATH"] = "{}/model".format(path+feature_name)

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from src.config import prediction_model_config as config
from src.model.simple_model import MySimpleModel
from src.train import fit_model, compile_model
from src.data_preparation import DataGenerator
from IPython.display import clear_output
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# !pip install jedi==0.17.2

# %%
dic_non_missing_data[feature_name].head()
# Out:
#    mouth_right_corner_x  ...                                              Image
# 0             28.614496  ...  [[238, 236, 237, 238, 240, 240, 239, 241, 241,...
# 1             35.122383  ...  [[219, 215, 204, 196, 204, 211, 212, 200, 180,...
# 2             33.726316  ...  [[144, 142, 159, 180, 188, 188, 184, 180, 167,...
# 3             37.245496  ...  [[193, 192, 193, 194, 194, 194, 193, 192, 168,...
# 4             31.191755  ...  [[147, 148, 160, 196, 215, 214, 216, 217, 219,...
#
# [5 rows x 3 columns]

# %%
df = dic_non_missing_data[feature_name]
df_train, df_test_val = split_data(df, test_size=0.3)
df_val, df_test = split_data(df_test_val, test_size=0.1)
print(df.shape, df_train.shape, df_val.shape, df_test.shape)

# fit the MinMaxScaler using the training data and then apply the scaler on the testing data before the prediction.
scaler = create_scaler(df_train.iloc[:,:-1])
save_to_pickle(scaler, config.TRAIN_SCALER_PATH)

train_generator = DataGenerator(df_train, 
                                batch_size=config.BATCH_SIZE,
                                augment= config.AUGMENT_TRAIN,
                                rgb_channels= config.RGB_CHANNELS,
                                normalize_image=config.NORMALIZE_IMAGE,
                                normalize_coordinates=config.NORMALIZE_COORDINATES, 
                                scaler=scaler)

val_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

test_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_VAL,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)
# Out:
# (2270, 3) (1589, 3) (612, 3) (69, 3)

# %%
my_model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)
compile_model(my_model, optimizer="adam", loss='mean_squared_error', metrics=['mae'])
my_model, history = fit_model(my_model, config.EPOCHS, train_generator, val_generator, config.WEIGHT_PATH)
# Out:
# Epoch 1/100
# 49/49 [==============================] - 3s 52ms/step - loss: 0.0833 - mae: 0.2213 - val_loss: 0.0183 - val_mae: 0.1008
#
# Epoch 00001: val_loss improved from inf to 0.01826, saving model to /content/gdrive/My Drive/saved/mouth_right_corner/weights/mouth_right_corner.ckpt
# Epoch 2/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0255 - mae: 0.1224 - val_loss: 0.0180 - val_mae: 0.0987
#
# Epoch 00002: val_loss improved from 0.01826 to 0.01798, saving model to /content/gdrive/My Drive/saved/mouth_right_corner/weights/mouth_right_corner.ckpt
# Epoch 3/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0191 - mae: 0.1040 - val_loss: 0.0121 - val_mae: 0.0817
#
# Epoch 00003: val_loss improved from 0.01798 to 0.01214, saving model to /content/gdrive/My Drive/saved/mouth_right_corner/weights/mouth_right_corner.ckpt
# Epoch 4/100
# 49/49 [==============================] - 2s 50ms/step - loss: 0.0178 - mae: 0.0991 - val_loss: 0.0134 - val_mae: 0.0855
#
# Epoch 00004: val_loss did not improve from 0.01214
# Epoch 5/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0155 - mae: 0.0928 - val_loss: 0.0107 - val_mae: 0.0757
#
# Epoch 00005: val_loss improved from 0.01214 to 0.01070, saving model to /content/gdrive/My Drive/saved/mouth_right_corner/weights/mouth_right_corner.ckpt
# Epoch 6/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0148 - mae: 0.0904 - val_loss: 0.0123 - val_mae: 0.0864
#
# Epoch 00006: val_loss did not improve from 0.01070
# Epoch 7/100
# 49/49 [==============================] - 2s 50ms/step - loss: 0.0148 - mae: 0.0901 - val_loss: 0.0093 - val_mae: 0.0740
#
# Epoch 00007: val_loss improved from 0.01070 to 0.00928, saving model to /content/gdrive/My Drive/saved/mouth_right_corner/weights/mouth_right_corner.ckpt
# Epoch 8/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0140 - mae: 0.0879 - val_loss: 0.0084 - val_mae: 0.0693
#
# Epoch 00008: val_loss improved from 0.00928 to 0.00839, saving model to /content/gdrive/My Drive/saved/mouth_right_corner/weights/mouth_right_corner.ckpt
# Epoch 9/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0112 - mae: 0.0793 - val_loss: 0.0091 - val_mae: 0.0701
#
# Epoch 00009: val_loss did not improve from 0.00839
# Epoch 10/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0109 - mae: 0.0768 - val_loss: 0.0089 - val_mae: 0.0654
#
# Epoch 00010: val_loss did not improve from 0.00839
# Epoch 11/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0122 - mae: 0.0800 - val_loss: 0.0113 - val_mae: 0.0800
#
# Epoch 00011: val_loss did not improve from 0.00839
# Epoch 12/100
# 49/49 [==============================] - 2s 50ms/step - loss: 0.0106 - mae: 0.0769 - val_loss: 0.0072 - val_mae: 0.0604
#
# Epoch 00012: val_loss improved from 0.00839 to 0.00722, saving model to /content/gdrive/My Drive/saved/mouth_right_corner/weights/mouth_right_corner.ckpt
# Epoch 13/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0101 - mae: 0.0733 - val_loss: 0.0079 - val_mae: 0.0665
#
# Epoch 00013: val_loss did not improve from 0.00722
# Epoch 14/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0100 - mae: 0.0718 - val_loss: 0.0063 - val_mae: 0.0594
#
# Epoch 00014: val_loss improved from 0.00722 to 0.00626, saving model to /content/gdrive/My Drive/saved/mouth_right_corner/weights/mouth_right_corner.ckpt
# Epoch 15/100
# 49/49 [==============================] - 2s 50ms/step - loss: 0.0093 - mae: 0.0705 - val_loss: 0.0086 - val_mae: 0.0673
#
# Epoch 00015: val_loss did not improve from 0.00626
# Epoch 16/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0083 - mae: 0.0663 - val_loss: 0.0083 - val_mae: 0.0690
#
# Epoch 00016: val_loss did not improve from 0.00626
# Epoch 17/100
# 49/49 [==============================] - 2s 50ms/step - loss: 0.0087 - mae: 0.0687 - val_loss: 0.0103 - val_mae: 0.0781
#
# Epoch 00017: val_loss did not improve from 0.00626
# Epoch 18/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0088 - mae: 0.0684 - val_loss: 0.0071 - val_mae: 0.0650
#
# Epoch 00018: val_loss did not improve from 0.00626
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 19/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0093 - mae: 0.0706 - val_loss: 0.0077 - val_mae: 0.0641
#
# Epoch 00019: val_loss did not improve from 0.00626
# Epoch 20/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0067 - mae: 0.0589 - val_loss: 0.0052 - val_mae: 0.0519
#
# Epoch 00020: val_loss improved from 0.00626 to 0.00520, saving model to /content/gdrive/My Drive/saved/mouth_right_corner/weights/mouth_right_corner.ckpt
# Epoch 21/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0067 - mae: 0.0594 - val_loss: 0.0041 - val_mae: 0.0512
#
# Epoch 00021: val_loss improved from 0.00520 to 0.00415, saving model to /content/gdrive/My Drive/saved/mouth_right_corner/weights/mouth_right_corner.ckpt
# Epoch 22/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0069 - mae: 0.0587 - val_loss: 0.0044 - val_mae: 0.0519
#
# Epoch 00022: val_loss did not improve from 0.00415
# Epoch 23/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0067 - mae: 0.0580 - val_loss: 0.0044 - val_mae: 0.0504
#
# Epoch 00023: val_loss did not improve from 0.00415
# Epoch 24/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0065 - mae: 0.0567 - val_loss: 0.0062 - val_mae: 0.0582
#
# Epoch 00024: val_loss did not improve from 0.00415
# Epoch 25/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0071 - mae: 0.0605 - val_loss: 0.0059 - val_mae: 0.0557
#
# Epoch 00025: val_loss did not improve from 0.00415
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 26/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0067 - mae: 0.0576 - val_loss: 0.0040 - val_mae: 0.0479
#
# Epoch 00026: val_loss improved from 0.00415 to 0.00405, saving model to /content/gdrive/My Drive/saved/mouth_right_corner/weights/mouth_right_corner.ckpt
# Epoch 27/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0060 - mae: 0.0565 - val_loss: 0.0054 - val_mae: 0.0543
#
# Epoch 00027: val_loss did not improve from 0.00405
# Epoch 28/100
# 49/49 [==============================] - 2s 50ms/step - loss: 0.0062 - mae: 0.0567 - val_loss: 0.0059 - val_mae: 0.0530
#
# Epoch 00028: val_loss did not improve from 0.00405
# Epoch 29/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0068 - mae: 0.0590 - val_loss: 0.0056 - val_mae: 0.0500
#
# Epoch 00029: val_loss did not improve from 0.00405
# Epoch 30/100
# 49/49 [==============================] - 2s 50ms/step - loss: 0.0063 - mae: 0.0578 - val_loss: 0.0047 - val_mae: 0.0485
#
# Epoch 00030: val_loss did not improve from 0.00405
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 31/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0067 - mae: 0.0579 - val_loss: 0.0039 - val_mae: 0.0476
#
# Epoch 00031: val_loss improved from 0.00405 to 0.00390, saving model to /content/gdrive/My Drive/saved/mouth_right_corner/weights/mouth_right_corner.ckpt
# Epoch 32/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0061 - mae: 0.0567 - val_loss: 0.0071 - val_mae: 0.0590
#
# Epoch 00032: val_loss did not improve from 0.00390
# Epoch 33/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0064 - mae: 0.0569 - val_loss: 0.0047 - val_mae: 0.0521
#
# Epoch 00033: val_loss did not improve from 0.00390
# Epoch 34/100
# 49/49 [==============================] - 2s 51ms/step - loss: 0.0059 - mae: 0.0557 - val_loss: 0.0034 - val_mae: 0.0426
#
# Epoch 00034: val_loss improved from 0.00390 to 0.00341, saving model to /content/gdrive/My Drive/saved/mouth_right_corner/weights/mouth_right_corner.ckpt
# Epoch 35/100
# 49/49 [==============================] - 2s 50ms/step - loss: 0.0054 - mae: 0.0533 - val_loss: 0.0050 - val_mae: 0.0521
#
# Epoch 00035: val_loss did not improve from 0.00341
# Epoch 36/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0068 - mae: 0.0595 - val_loss: 0.0054 - val_mae: 0.0515
#
# Epoch 00036: val_loss did not improve from 0.00341
# Epoch 37/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0061 - mae: 0.0561 - val_loss: 0.0050 - val_mae: 0.0492
#
# Epoch 00037: val_loss did not improve from 0.00341
# Epoch 38/100
# 49/49 [==============================] - 2s 50ms/step - loss: 0.0061 - mae: 0.0558 - val_loss: 0.0042 - val_mae: 0.0449
#
# Epoch 00038: val_loss did not improve from 0.00341
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 39/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0064 - mae: 0.0575 - val_loss: 0.0050 - val_mae: 0.0515
#
# Epoch 00039: val_loss did not improve from 0.00341
# Epoch 40/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0060 - mae: 0.0555 - val_loss: 0.0056 - val_mae: 0.0523
#
# Epoch 00040: val_loss did not improve from 0.00341
# Epoch 41/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0066 - mae: 0.0589 - val_loss: 0.0042 - val_mae: 0.0477
#
# Epoch 00041: val_loss did not improve from 0.00341
# Epoch 42/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0061 - mae: 0.0565 - val_loss: 0.0048 - val_mae: 0.0491
#
# Epoch 00042: val_loss did not improve from 0.00341
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 00042: early stopping

# %%
# Recreat the same structure of the model and load its saved weights then build it by predicting a random input then save the model
from src.train import compile_model
from tensorflow.keras.models import load_model

model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)

model.load_weights(config.WEIGHT_PATH)
model.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
model.save(config.MODEL_PATH)
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/saved/mouth_right_corner/model/assets

# %%
# load the model to check it
m = load_model(config.MODEL_PATH, compile=False)
m.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
# Out:
# array([[0.5267028, 0.4393251]], dtype=float32)

# %%
compile_model(m)
m.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0573 - mae: 0.0362
# [0.05925369635224342, 0.03726821020245552]

# %% [markdown]
# #### **Evaluate the model**

# %%
my_model.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0023 - mae: 0.0370
# [0.0022929690312594175, 0.0370158776640892]

# %%
# Retrieve a list of list results on training and test data sets for each training epoch
loss     = history.history['loss']
val_loss = history.history['val_loss']
epochs   = range(len(loss))
# Plot training and validation loss per epoch
plt.plot(epochs,loss, color='red' , label='training loss')
plt.plot(epochs, val_loss, label='validation loss')
plt.legend()
plt.title ('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
test_generator_with_augmentation =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

# %%
batch = test_generator_with_augmentation.__getitem__(0)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_augmented_results.png", "augmented")

# %%
batch = test_generator.__getitem__(0)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_normal_results.png", "normal")
