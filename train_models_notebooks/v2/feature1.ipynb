# %%
feature_index = 1

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !rm -rf face-landmark-detection
# !git clone --branch part2 https://github.com/mariaafara/face-landmark-detection.git
# Out:
# Cloning into 'face-landmark-detection'...
# remote: Enumerating objects: 195, done.
# remote: Counting objects: 100% (195/195), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 195 (delta 73), reused 160 (delta 39), pack-reused 0
# Receiving objects: 100% (195/195), 4.95 MiB | 17.80 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %%
cd face-landmark-detection/
# Out:
# /content/gdrive/MyDrive/face-landmark-detection

# %%
import os
os.environ['KAGGLE_USERNAME'] = "" # username from the json file
os.environ['KAGGLE_KEY'] = "" # key from the json file
# Crearting a Client to host the Kaggle API
# !pip install -q kaggle
# !kaggle datasets download mariaafara/Facial-Landmarks
# !unzip Facial-Landmarks.zip # -d facial-keypoints-detection
# Out:
# Downloading Facial-Landmarks.zip to /content/gdrive/MyDrive/face-landmark-detection
#  92% 129M/141M [00:01<00:00, 86.0MB/s]
# 100% 141M/141M [00:01<00:00, 121MB/s]
# Archive:  Facial-Landmarks.zip
#   inflating: dic_missing_data.pkl
#   inflating: dic_train_data.pkl

# %%
ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
from src.utils import *
dic_non_missing_data = load_from_pickle("dic_train_data.pkl")
features = list(dic_non_missing_data.keys())
feature_name = features[feature_index]
os.environ["EPOCHS"] = "100"
os.environ["RGB_CHANNELS"] = "false"
os.environ["PATIENCE_EARLY_STOPPING"] = "8"
# os.environ["PATIENCE_LR"] = "5"
path = F"/content/gdrive/My Drive/saved/"
os.environ["TRAIN_SCALER_PATH"] = "{}_scaler.pkl".format(path+feature_name)
os.environ["WEIGHT_PATH"] = "{}/weights/{}.ckpt".format(path+feature_name, feature_name)
os.environ["FEATURES_DIMENSIONS"] = "2"
os.environ["MODEL_PATH"] = "{}/model".format(path+feature_name)

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from src.config import prediction_model_config as config
from src.model.simple_model import MySimpleModel
from src.train import fit_model, compile_model
from src.data_preparation import DataGenerator
from IPython.display import clear_output
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# !pip install jedi==0.17.2

# %%
dic_non_missing_data[feature_name].head()
# Out:
#    right_eye_center_x  ...                                              Image
# 0           30.227008  ...  [[238, 236, 237, 238, 240, 240, 239, 241, 241,...
# 1           29.949277  ...  [[219, 215, 204, 196, 204, 211, 212, 200, 180,...
# 2           30.903789  ...  [[144, 142, 159, 180, 188, 188, 184, 180, 167,...
# 3           32.023096  ...  [[193, 192, 193, 194, 194, 194, 193, 192, 168,...
# 4           32.244810  ...  [[147, 148, 160, 196, 215, 214, 216, 217, 219,...
#
# [5 rows x 3 columns]

# %%
df = dic_non_missing_data[feature_name]
df_train, df_test_val = split_data(df, test_size=0.3)
df_val, df_test = split_data(df_test_val, test_size=0.1)
print(df.shape, df_train.shape, df_val.shape, df_test.shape)

# fit the MinMaxScaler using the training data and then apply the scaler on the testing data before the prediction.
scaler = create_scaler(df_train.iloc[:,:-1])
save_to_pickle(scaler, config.TRAIN_SCALER_PATH)

train_generator = DataGenerator(df_train, 
                                batch_size=config.BATCH_SIZE,
                                augment= config.AUGMENT_TRAIN,
                                rgb_channels= config.RGB_CHANNELS,
                                normalize_image=config.NORMALIZE_IMAGE,
                                normalize_coordinates=config.NORMALIZE_COORDINATES, 
                                scaler=scaler)

val_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

test_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_VAL,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)
# Out:
# (7036, 3) (4925, 3) (1899, 3) (212, 3)

# %%
my_model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)
compile_model(my_model, optimizer="adam", loss='mean_squared_error', metrics=['mae'])
my_model, history = fit_model(my_model, config.EPOCHS, train_generator, val_generator, config.WEIGHT_PATH)
# Out:
# Epoch 1/100
# 153/153 [==============================] - 11s 51ms/step - loss: 0.0306 - mae: 0.1253 - val_loss: 0.0037 - val_mae: 0.0461
#
# Epoch 00001: val_loss improved from inf to 0.00367, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 2/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0046 - mae: 0.0497 - val_loss: 0.0026 - val_mae: 0.0388
#
# Epoch 00002: val_loss improved from 0.00367 to 0.00264, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 3/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0035 - mae: 0.0433 - val_loss: 0.0025 - val_mae: 0.0379
#
# Epoch 00003: val_loss improved from 0.00264 to 0.00253, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 4/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0034 - mae: 0.0418 - val_loss: 0.0028 - val_mae: 0.0392
#
# Epoch 00004: val_loss did not improve from 0.00253
# Epoch 5/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0032 - mae: 0.0408 - val_loss: 0.0038 - val_mae: 0.0482
#
# Epoch 00005: val_loss did not improve from 0.00253
# Epoch 6/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0034 - mae: 0.0414 - val_loss: 0.0020 - val_mae: 0.0333
#
# Epoch 00006: val_loss improved from 0.00253 to 0.00196, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 7/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0029 - mae: 0.0376 - val_loss: 0.0017 - val_mae: 0.0307
#
# Epoch 00007: val_loss improved from 0.00196 to 0.00167, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 8/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0027 - mae: 0.0362 - val_loss: 0.0017 - val_mae: 0.0292
#
# Epoch 00008: val_loss did not improve from 0.00167
# Epoch 9/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0024 - mae: 0.0351 - val_loss: 0.0019 - val_mae: 0.0328
#
# Epoch 00009: val_loss did not improve from 0.00167
# Epoch 10/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0027 - mae: 0.0368 - val_loss: 0.0015 - val_mae: 0.0278
#
# Epoch 00010: val_loss improved from 0.00167 to 0.00154, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 11/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0021 - mae: 0.0333 - val_loss: 0.0017 - val_mae: 0.0299
#
# Epoch 00011: val_loss did not improve from 0.00154
# Epoch 12/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0021 - mae: 0.0326 - val_loss: 0.0020 - val_mae: 0.0341
#
# Epoch 00012: val_loss did not improve from 0.00154
# Epoch 13/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0023 - mae: 0.0340 - val_loss: 0.0014 - val_mae: 0.0274
#
# Epoch 00013: val_loss improved from 0.00154 to 0.00139, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 14/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0022 - mae: 0.0325 - val_loss: 0.0017 - val_mae: 0.0299
#
# Epoch 00014: val_loss did not improve from 0.00139
# Epoch 15/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0021 - mae: 0.0327 - val_loss: 0.0014 - val_mae: 0.0272
#
# Epoch 00015: val_loss improved from 0.00139 to 0.00135, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 16/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0013 - val_mae: 0.0255
#
# Epoch 00016: val_loss improved from 0.00135 to 0.00125, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 17/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0020 - mae: 0.0314 - val_loss: 0.0012 - val_mae: 0.0265
#
# Epoch 00017: val_loss improved from 0.00125 to 0.00125, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 18/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0020 - mae: 0.0311 - val_loss: 0.0015 - val_mae: 0.0275
#
# Epoch 00018: val_loss did not improve from 0.00125
# Epoch 19/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0022 - mae: 0.0321 - val_loss: 0.0012 - val_mae: 0.0256
#
# Epoch 00019: val_loss improved from 0.00125 to 0.00121, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 20/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0019 - mae: 0.0302 - val_loss: 0.0013 - val_mae: 0.0259
#
# Epoch 00020: val_loss did not improve from 0.00121
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 21/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0017 - mae: 0.0280 - val_loss: 0.0010 - val_mae: 0.0228
#
# Epoch 00021: val_loss improved from 0.00121 to 0.00102, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 22/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0015 - mae: 0.0264 - val_loss: 9.8500e-04 - val_mae: 0.0219
#
# Epoch 00022: val_loss improved from 0.00102 to 0.00098, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 23/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0016 - mae: 0.0263 - val_loss: 0.0011 - val_mae: 0.0228
#
# Epoch 00023: val_loss did not improve from 0.00098
# Epoch 24/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0014 - mae: 0.0254 - val_loss: 9.8224e-04 - val_mae: 0.0222
#
# Epoch 00024: val_loss improved from 0.00098 to 0.00098, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 25/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0014 - mae: 0.0257 - val_loss: 9.0623e-04 - val_mae: 0.0210
#
# Epoch 00025: val_loss improved from 0.00098 to 0.00091, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 26/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0014 - mae: 0.0257 - val_loss: 7.5776e-04 - val_mae: 0.0197
#
# Epoch 00026: val_loss improved from 0.00091 to 0.00076, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 27/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0015 - mae: 0.0258 - val_loss: 8.0886e-04 - val_mae: 0.0201
#
# Epoch 00027: val_loss did not improve from 0.00076
# Epoch 28/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0015 - mae: 0.0254 - val_loss: 8.5739e-04 - val_mae: 0.0217
#
# Epoch 00028: val_loss did not improve from 0.00076
# Epoch 29/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0015 - mae: 0.0258 - val_loss: 7.7242e-04 - val_mae: 0.0196
#
# Epoch 00029: val_loss did not improve from 0.00076
# Epoch 30/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0014 - mae: 0.0255 - val_loss: 7.3538e-04 - val_mae: 0.0206
#
# Epoch 00030: val_loss improved from 0.00076 to 0.00074, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 31/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0014 - mae: 0.0249 - val_loss: 8.6122e-04 - val_mae: 0.0205
#
# Epoch 00031: val_loss did not improve from 0.00074
# Epoch 32/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0013 - mae: 0.0247 - val_loss: 8.0734e-04 - val_mae: 0.0205
#
# Epoch 00032: val_loss did not improve from 0.00074
# Epoch 33/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0015 - mae: 0.0252 - val_loss: 8.4831e-04 - val_mae: 0.0198
#
# Epoch 00033: val_loss did not improve from 0.00074
# Epoch 34/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0013 - mae: 0.0248 - val_loss: 8.3188e-04 - val_mae: 0.0201
#
# Epoch 00034: val_loss did not improve from 0.00074
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 35/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0015 - mae: 0.0253 - val_loss: 7.9213e-04 - val_mae: 0.0203
#
# Epoch 00035: val_loss did not improve from 0.00074
# Epoch 36/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0012 - mae: 0.0238 - val_loss: 7.1632e-04 - val_mae: 0.0197
#
# Epoch 00036: val_loss improved from 0.00074 to 0.00072, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 37/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0013 - mae: 0.0244 - val_loss: 7.7890e-04 - val_mae: 0.0194
#
# Epoch 00037: val_loss did not improve from 0.00072
# Epoch 38/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0013 - mae: 0.0241 - val_loss: 8.2764e-04 - val_mae: 0.0197
#
# Epoch 00038: val_loss did not improve from 0.00072
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 39/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0014 - mae: 0.0245 - val_loss: 9.6848e-04 - val_mae: 0.0201
#
# Epoch 00039: val_loss did not improve from 0.00072
# Epoch 40/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0013 - mae: 0.0243 - val_loss: 8.4237e-04 - val_mae: 0.0203
#
# Epoch 00040: val_loss did not improve from 0.00072
# Epoch 41/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0012 - mae: 0.0242 - val_loss: 6.9755e-04 - val_mae: 0.0190
#
# Epoch 00041: val_loss improved from 0.00072 to 0.00070, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 42/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0013 - mae: 0.0241 - val_loss: 6.9972e-04 - val_mae: 0.0190
#
# Epoch 00042: val_loss did not improve from 0.00070
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 43/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0013 - mae: 0.0240 - val_loss: 6.0793e-04 - val_mae: 0.0185
#
# Epoch 00043: val_loss improved from 0.00070 to 0.00061, saving model to /content/gdrive/My Drive/saved/right_eye_center/weights/right_eye_center.ckpt
# Epoch 44/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0014 - mae: 0.0250 - val_loss: 8.1655e-04 - val_mae: 0.0200
#
# Epoch 00044: val_loss did not improve from 0.00061
# Epoch 45/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0013 - mae: 0.0249 - val_loss: 8.7766e-04 - val_mae: 0.0199
#
# Epoch 00045: val_loss did not improve from 0.00061
# Epoch 46/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0015 - mae: 0.0244 - val_loss: 8.5518e-04 - val_mae: 0.0204
#
# Epoch 00046: val_loss did not improve from 0.00061
# Epoch 47/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0014 - mae: 0.0249 - val_loss: 9.3716e-04 - val_mae: 0.0206
#
# Epoch 00047: val_loss did not improve from 0.00061
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 48/100
# 153/153 [==============================] - 7s 45ms/step - loss: 0.0014 - mae: 0.0246 - val_loss: 7.7327e-04 - val_mae: 0.0195
#
# Epoch 00048: val_loss did not improve from 0.00061
# Epoch 49/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0014 - mae: 0.0244 - val_loss: 7.9231e-04 - val_mae: 0.0192
#
# Epoch 00049: val_loss did not improve from 0.00061
# Epoch 50/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0013 - mae: 0.0239 - val_loss: 6.9084e-04 - val_mae: 0.0188
#
# Epoch 00050: val_loss did not improve from 0.00061
# Epoch 51/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0015 - mae: 0.0246 - val_loss: 6.7138e-04 - val_mae: 0.0181
#
# Epoch 00051: val_loss did not improve from 0.00061
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# Epoch 00051: early stopping

# %%
# Recreat the same structure of the model and load its saved weights then build it by predicting a random input then save the model
from src.train import compile_model
from tensorflow.keras.models import load_model

model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)

model.load_weights(config.WEIGHT_PATH)
model.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
model.save(config.MODEL_PATH)
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/saved/right_eye_center/model/assets

# %%
# load the model to check it
m = load_model(config.MODEL_PATH, compile=False)
m.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
# Out:
# array([[0.29390594, 0.5014823 ]], dtype=float32)

# %%
compile_model(m)
m.evaluate(test_generator)
# Out:
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0241 - mae: 0.0153
# [0.025243675336241722, 0.016054602339863777]

# %% [markdown]
# #### **Evaluate the model**

# %%
my_model.evaluate(test_generator)
# Out:
# 6/6 [==============================] - 0s 5ms/step - loss: 5.5095e-04 - mae: 0.0161
# [0.0005509465117938817, 0.016077423468232155]

# %%
# Retrieve a list of list results on training and test data sets for each training epoch
loss     = history.history['loss']
val_loss = history.history['val_loss']
epochs   = range(len(loss))
# Plot training and validation loss per epoch
plt.plot(epochs,loss, color='red' , label='training loss')
plt.plot(epochs, val_loss, label='validation loss')
plt.legend()
plt.title ('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
test_generator_with_augmentation =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

# %%
batch = test_generator_with_augmentation.__getitem__(2)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_augmented_results.png", "augmented")

# %%
batch = test_generator.__getitem__(2)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_normal_results.png", "normal")
