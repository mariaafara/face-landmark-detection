# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/MyDrive/

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !rm -rf face-landmark-detection
# !git clone --branch part2 https://github.com/mariaafara/face-landmark-detection.git
# Out:
# Cloning into 'face-landmark-detection'...
# remote: Enumerating objects: 195, done.
# remote: Counting objects: 100% (195/195), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 195 (delta 73), reused 160 (delta 39), pack-reused 0
# Receiving objects: 100% (195/195), 4.95 MiB | 18.18 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %%
cd face-landmark-detection/
# Out:
# /content/gdrive/MyDrive/face-landmark-detection

# %%
import os
os.environ['KAGGLE_USERNAME'] = "" # username from the json file
os.environ['KAGGLE_KEY'] = "" # key from the json file
# Crearting a Client to host the Kaggle API
# !pip install -q kaggle
# !kaggle datasets download mariaafara/Facial-Landmarks
# !unzip Facial-Landmarks.zip # -d facial-keypoints-detection
# Out:
# Downloading Facial-Landmarks.zip to /content/gdrive/My Drive/face-landmark-detection
#  94% 132M/141M [00:01<00:00, 57.1MB/s]
# 100% 141M/141M [00:01<00:00, 91.0MB/s]
# Archive:  Facial-Landmarks.zip
#   inflating: dic_missing_data.pkl
#   inflating: dic_train_data.pkl

# %%
ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
feature_index = 0
from src.utils import *
dic_non_missing_data = load_from_pickle("dic_train_data.pkl")
features = list(dic_non_missing_data.keys())
feature_name = features[feature_index]
os.environ["EPOCHS"] = "100"
os.environ["RGB_CHANNELS"] = "false"
os.environ["PATIENCE_EARLY_STOPPING"] = "8"
# os.environ["PATIENCE_LR"] = "5"
path = F"/content/gdrive/My Drive/saved/"
os.environ["TRAIN_SCALER_PATH"] = "{}_scaler.pkl".format(path+feature_name)
os.environ["WEIGHT_PATH"] = "{}/weights/{}.ckpt".format(path+feature_name, feature_name)
os.environ["FEATURES_DIMENSIONS"] = "2"
os.environ["MODEL_PATH"] = "{}/model".format(path+feature_name)

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from src.config import prediction_model_config as config
from src.model.simple_model import MySimpleModel
from src.train import fit_model, compile_model
from src.data_preparation import DataGenerator
from IPython.display import clear_output
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# !pip install jedi==0.17.2

# %%
dic_non_missing_data[feature_name].head()
# Out:
#    left_eye_center_x  ...                                              Image
# 0          66.033564  ...  [[238, 236, 237, 238, 240, 240, 239, 241, 241,...
# 1          64.332936  ...  [[219, 215, 204, 196, 204, 211, 212, 200, 180,...
# 2          65.057053  ...  [[144, 142, 159, 180, 188, 188, 184, 180, 167,...
# 3          65.225739  ...  [[193, 192, 193, 194, 194, 194, 193, 192, 168,...
# 4          66.725301  ...  [[147, 148, 160, 196, 215, 214, 216, 217, 219,...
#
# [5 rows x 3 columns]

# %%
df = dic_non_missing_data[feature_name]
df_train, df_test_val = split_data(df, test_size=0.3)
df_val, df_test = split_data(df_test_val, test_size=0.1)
print(df.shape, df_train.shape, df_val.shape, df_test.shape)

# fit the MinMaxScaler using the training data and then apply the scaler on the testing data before the prediction.
scaler = create_scaler(df_train.iloc[:,:-1])
save_to_pickle(scaler, config.TRAIN_SCALER_PATH)

train_generator = DataGenerator(df_train, 
                                batch_size=config.BATCH_SIZE,
                                augment= config.AUGMENT_TRAIN,
                                rgb_channels= config.RGB_CHANNELS,
                                normalize_image=config.NORMALIZE_IMAGE,
                                normalize_coordinates=config.NORMALIZE_COORDINATES, 
                                scaler=scaler)

val_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

test_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_VAL,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)
# Out:
# (7039, 3) (4927, 3) (1900, 3) (212, 3)

# %%
my_model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)
compile_model(my_model, optimizer="adam", loss='mean_squared_error', metrics=['mae'])
my_model, history = fit_model(my_model, config.EPOCHS, train_generator, val_generator, config.WEIGHT_PATH)
# Out:
# Epoch 1/100
# 153/153 [==============================] - 15s 50ms/step - loss: 0.0450 - mae: 0.1511 - val_loss: 0.0069 - val_mae: 0.0608
#
# Epoch 00001: val_loss improved from inf to 0.00689, saving model to /content/gdrive/My Drive/saved/left_eye_center/weights/left_eye_center.ckpt
# Epoch 2/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0078 - mae: 0.0660 - val_loss: 0.0052 - val_mae: 0.0488
#
# Epoch 00002: val_loss improved from 0.00689 to 0.00523, saving model to /content/gdrive/My Drive/saved/left_eye_center/weights/left_eye_center.ckpt
# Epoch 3/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0067 - mae: 0.0603 - val_loss: 0.0053 - val_mae: 0.0501
#
# Epoch 00003: val_loss did not improve from 0.00523
# Epoch 4/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0054 - mae: 0.0539 - val_loss: 0.0058 - val_mae: 0.0508
#
# Epoch 00004: val_loss did not improve from 0.00523
# Epoch 5/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0050 - mae: 0.0514 - val_loss: 0.0049 - val_mae: 0.0441
#
# Epoch 00005: val_loss improved from 0.00523 to 0.00492, saving model to /content/gdrive/My Drive/saved/left_eye_center/weights/left_eye_center.ckpt
# Epoch 6/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0050 - mae: 0.0517 - val_loss: 0.0047 - val_mae: 0.0434
#
# Epoch 00006: val_loss improved from 0.00492 to 0.00466, saving model to /content/gdrive/My Drive/saved/left_eye_center/weights/left_eye_center.ckpt
# Epoch 7/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0047 - mae: 0.0490 - val_loss: 0.0034 - val_mae: 0.0389
#
# Epoch 00007: val_loss improved from 0.00466 to 0.00341, saving model to /content/gdrive/My Drive/saved/left_eye_center/weights/left_eye_center.ckpt
# Epoch 8/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0047 - mae: 0.0485 - val_loss: 0.0036 - val_mae: 0.0420
#
# Epoch 00008: val_loss did not improve from 0.00341
# Epoch 9/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0044 - mae: 0.0472 - val_loss: 0.0043 - val_mae: 0.0428
#
# Epoch 00009: val_loss did not improve from 0.00341
# Epoch 10/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0040 - mae: 0.0457 - val_loss: 0.0035 - val_mae: 0.0400
#
# Epoch 00010: val_loss did not improve from 0.00341
# Epoch 11/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0040 - mae: 0.0454 - val_loss: 0.0028 - val_mae: 0.0384
#
# Epoch 00011: val_loss improved from 0.00341 to 0.00279, saving model to /content/gdrive/My Drive/saved/left_eye_center/weights/left_eye_center.ckpt
# Epoch 12/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0038 - mae: 0.0430 - val_loss: 0.0024 - val_mae: 0.0364
#
# Epoch 00012: val_loss improved from 0.00279 to 0.00237, saving model to /content/gdrive/My Drive/saved/left_eye_center/weights/left_eye_center.ckpt
# Epoch 13/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0036 - mae: 0.0424 - val_loss: 0.0039 - val_mae: 0.0432
#
# Epoch 00013: val_loss did not improve from 0.00237
# Epoch 14/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0036 - mae: 0.0422 - val_loss: 0.0031 - val_mae: 0.0410
#
# Epoch 00014: val_loss did not improve from 0.00237
# Epoch 15/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0037 - mae: 0.0439 - val_loss: 0.0033 - val_mae: 0.0359
#
# Epoch 00015: val_loss did not improve from 0.00237
# Epoch 16/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0038 - mae: 0.0434 - val_loss: 0.0027 - val_mae: 0.0346
#
# Epoch 00016: val_loss did not improve from 0.00237
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 17/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0029 - mae: 0.0377 - val_loss: 0.0021 - val_mae: 0.0309
#
# Epoch 00017: val_loss improved from 0.00237 to 0.00212, saving model to /content/gdrive/My Drive/saved/left_eye_center/weights/left_eye_center.ckpt
# Epoch 18/100
# 153/153 [==============================] - 7s 48ms/step - loss: 0.0028 - mae: 0.0359 - val_loss: 0.0019 - val_mae: 0.0300
#
# Epoch 00018: val_loss improved from 0.00212 to 0.00192, saving model to /content/gdrive/My Drive/saved/left_eye_center/weights/left_eye_center.ckpt
# Epoch 19/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0026 - mae: 0.0351 - val_loss: 0.0019 - val_mae: 0.0297
#
# Epoch 00019: val_loss improved from 0.00192 to 0.00189, saving model to /content/gdrive/My Drive/saved/left_eye_center/weights/left_eye_center.ckpt
# Epoch 20/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0028 - mae: 0.0366 - val_loss: 0.0018 - val_mae: 0.0295
#
# Epoch 00020: val_loss improved from 0.00189 to 0.00184, saving model to /content/gdrive/My Drive/saved/left_eye_center/weights/left_eye_center.ckpt
# Epoch 21/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0027 - mae: 0.0360 - val_loss: 0.0016 - val_mae: 0.0298
#
# Epoch 00021: val_loss improved from 0.00184 to 0.00164, saving model to /content/gdrive/My Drive/saved/left_eye_center/weights/left_eye_center.ckpt
# Epoch 22/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0026 - mae: 0.0352 - val_loss: 0.0021 - val_mae: 0.0325
#
# Epoch 00022: val_loss did not improve from 0.00164
# Epoch 23/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0026 - mae: 0.0355 - val_loss: 0.0017 - val_mae: 0.0293
#
# Epoch 00023: val_loss did not improve from 0.00164
# Epoch 24/100
# 153/153 [==============================] - 7s 48ms/step - loss: 0.0025 - mae: 0.0356 - val_loss: 0.0017 - val_mae: 0.0295
#
# Epoch 00024: val_loss did not improve from 0.00164
# Epoch 25/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0027 - mae: 0.0353 - val_loss: 0.0021 - val_mae: 0.0310
#
# Epoch 00025: val_loss did not improve from 0.00164
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 26/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0025 - mae: 0.0342 - val_loss: 0.0017 - val_mae: 0.0278
#
# Epoch 00026: val_loss did not improve from 0.00164
# Epoch 27/100
# 153/153 [==============================] - 7s 47ms/step - loss: 0.0023 - mae: 0.0331 - val_loss: 0.0020 - val_mae: 0.0301
#
# Epoch 00027: val_loss did not improve from 0.00164
# Epoch 28/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0023 - mae: 0.0331 - val_loss: 0.0018 - val_mae: 0.0293
#
# Epoch 00028: val_loss did not improve from 0.00164
# Epoch 29/100
# 153/153 [==============================] - 7s 46ms/step - loss: 0.0024 - mae: 0.0332 - val_loss: 0.0018 - val_mae: 0.0291
#
# Epoch 00029: val_loss did not improve from 0.00164
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 00029: early stopping

# %%
# Recreat the same structure of the model and load its saved weights then build it by predicting a random input then save the model
from src.train import compile_model
from tensorflow.keras.models import load_model

model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)

model.load_weights(config.WEIGHT_PATH)
model.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
model.save(config.MODEL_PATH)
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/saved/left_eye_center/model/assets

# %%
# load the model to check it
m = load_model(config.MODEL_PATH, compile=False)
m.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
# Out:
# array([[0.5293809, 0.3979947]], dtype=float32)

# %%
compile_model(m)
m.evaluate(test_generator)
# Out:
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0367 - mae: 0.0238
# [0.037382688373327255, 0.024192122742533684]

# %% [markdown]
# #### **Evaluate the model**

# %%
my_model.evaluate(test_generator)
# Out:
# 6/6 [==============================] - 0s 4ms/step - loss: 8.9621e-04 - mae: 0.0219
# [0.0008962124702520669, 0.02187747322022915]

# %%
# Retrieve a list of list results on training and test data sets for each training epoch
loss     = history.history['loss']
val_loss = history.history['val_loss']
epochs   = range(len(loss))
# Plot training and validation loss per epoch
plt.plot(epochs,loss, color='red' , label='training loss')
plt.plot(epochs, val_loss, label='validation loss')
plt.legend()
plt.title ('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
test_generator_with_augmentation =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

# %%
batch = test_generator_with_augmentation.__getitem__(3)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_augmented_results.png", "augmented")

# %%
batch = test_generator.__getitem__(3)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_normal_results.png", "normal")
