# %%
feature_index = 7

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
cd gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !rm -rf face-landmark-detection
# !git clone --branch part2 https://github.com/mariaafara/face-landmark-detection.git
# Out:
# Cloning into 'face-landmark-detection'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 203 (delta 79), reused 166 (delta 43), pack-reused 0
# Receiving objects: 100% (203/203), 4.95 MiB | 17.86 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
cd face-landmark-detection/
# Out:
# /content/gdrive/MyDrive/face-landmark-detection

# %%
import os
os.environ['KAGGLE_USERNAME'] = "mariaafara" # username from the json file
os.environ['KAGGLE_KEY'] = "" # key from the json file
# Crearting a Client to host the Kaggle API
# !pip install -q kaggle
# !kaggle datasets download mariaafara/Facial-Landmarks
# !unzip Facial-Landmarks.zip # -d facial-keypoints-detection
# Out:
# Downloading Facial-Landmarks.zip to /content/gdrive/MyDrive/face-landmark-detection
# 100% 140M/141M [00:01<00:00, 87.5MB/s]
# 100% 141M/141M [00:01<00:00, 116MB/s]
# Archive:  Facial-Landmarks.zip
#   inflating: dic_missing_data.pkl
#   inflating: dic_train_data.pkl

# %%
ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
# %ls
# Out:
# data_preparation.ipynb  images/                     src/
# dic_missing_data.pkl    label_missing_values.ipynb  train_models_notebooks/
# dic_train_data.pkl      prediction_model.ipynb
# Facial-Landmarks.zip    README.md

# %%
from src.utils import *
dic_non_missing_data = load_from_pickle("dic_train_data.pkl")
features = list(dic_non_missing_data.keys())
feature_name = features[feature_index]
os.environ["EPOCHS"] = "100"
os.environ["RGB_CHANNELS"] = "false"
os.environ["PATIENCE_EARLY_STOPPING"] = "8"
# os.environ["PATIENCE_LR"] = "5"
path = F"/content/gdrive/My Drive/saved/"
os.environ["TRAIN_SCALER_PATH"] = "{}_scaler.pkl".format(path+feature_name)
os.environ["WEIGHT_PATH"] = "{}/weights/{}.ckpt".format(path+feature_name, feature_name)
os.environ["FEATURES_DIMENSIONS"] = "2"
os.environ["MODEL_PATH"] = "{}/model".format(path+feature_name)

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from src.config import prediction_model_config as config
from src.model.simple_model import MySimpleModel
from src.train import fit_model, compile_model
from src.data_preparation import DataGenerator
from IPython.display import clear_output
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# !pip install jedi==0.17.2

# %%
dic_non_missing_data[feature_name].head()
# Out:
#    left_eyebrow_outer_end_x  ...                                              Image
# 0                 80.227128  ...  [[238, 236, 237, 238, 240, 240, 239, 241, 241,...
# 1                 78.634213  ...  [[219, 215, 204, 196, 204, 211, 212, 200, 180,...
# 2                 78.887368  ...  [[144, 142, 159, 180, 188, 188, 184, 180, 167,...
# 3                 77.910261  ...  [[193, 192, 193, 194, 194, 194, 193, 192, 168,...
# 4                 77.762945  ...  [[147, 148, 160, 196, 215, 214, 216, 217, 219,...
#
# [5 rows x 3 columns]

# %%
df = dic_non_missing_data[feature_name]
df_train, df_test_val = split_data(df, test_size=0.3)
df_val, df_test = split_data(df_test_val, test_size=0.1)
print(df.shape, df_train.shape, df_val.shape, df_test.shape)

# fit the MinMaxScaler using the training data and then apply the scaler on the testing data before the prediction.
scaler = create_scaler(df_train.iloc[:,:-1])
save_to_pickle(scaler, config.TRAIN_SCALER_PATH)

train_generator = DataGenerator(df_train, 
                                batch_size=config.BATCH_SIZE,
                                augment= config.AUGMENT_TRAIN,
                                rgb_channels= config.RGB_CHANNELS,
                                normalize_image=config.NORMALIZE_IMAGE,
                                normalize_coordinates=config.NORMALIZE_COORDINATES, 
                                scaler=scaler)

val_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

test_generator =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_VAL,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)
# Out:
# (2225, 3) (1557, 3) (601, 3) (67, 3)

# %%
my_model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)
compile_model(my_model, optimizer="adam", loss='mean_squared_error', metrics=['mae'])
my_model, history = fit_model(my_model, config.EPOCHS, train_generator, val_generator, config.WEIGHT_PATH)
# Out:
# Epoch 1/100
# 48/48 [==============================] - 7s 69ms/step - loss: 0.1288 - mae: 0.2779 - val_loss: 0.0251 - val_mae: 0.1272
#
# Epoch 00001: val_loss improved from inf to 0.02505, saving model to /content/gdrive/My Drive/saved/left_eyebrow_outer_end/weights/left_eyebrow_outer_end.ckpt
# Epoch 2/100
# 48/48 [==============================] - 2s 49ms/step - loss: 0.0226 - mae: 0.1154 - val_loss: 0.0127 - val_mae: 0.0882
#
# Epoch 00002: val_loss improved from 0.02505 to 0.01268, saving model to /content/gdrive/My Drive/saved/left_eyebrow_outer_end/weights/left_eyebrow_outer_end.ckpt
# Epoch 3/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0169 - mae: 0.0987 - val_loss: 0.0145 - val_mae: 0.0861
#
# Epoch 00003: val_loss did not improve from 0.01268
# Epoch 4/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0145 - mae: 0.0896 - val_loss: 0.0113 - val_mae: 0.0793
#
# Epoch 00004: val_loss improved from 0.01268 to 0.01131, saving model to /content/gdrive/My Drive/saved/left_eyebrow_outer_end/weights/left_eyebrow_outer_end.ckpt
# Epoch 5/100
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0131 - mae: 0.0846 - val_loss: 0.0122 - val_mae: 0.0892
#
# Epoch 00005: val_loss did not improve from 0.01131
# Epoch 6/100
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0113 - mae: 0.0793 - val_loss: 0.0070 - val_mae: 0.0579
#
# Epoch 00006: val_loss improved from 0.01131 to 0.00704, saving model to /content/gdrive/My Drive/saved/left_eyebrow_outer_end/weights/left_eyebrow_outer_end.ckpt
# Epoch 7/100
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0108 - mae: 0.0759 - val_loss: 0.0052 - val_mae: 0.0549
#
# Epoch 00007: val_loss improved from 0.00704 to 0.00521, saving model to /content/gdrive/My Drive/saved/left_eyebrow_outer_end/weights/left_eyebrow_outer_end.ckpt
# Epoch 8/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0098 - mae: 0.0723 - val_loss: 0.0051 - val_mae: 0.0513
#
# Epoch 00008: val_loss improved from 0.00521 to 0.00511, saving model to /content/gdrive/My Drive/saved/left_eyebrow_outer_end/weights/left_eyebrow_outer_end.ckpt
# Epoch 9/100
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0084 - mae: 0.0663 - val_loss: 0.0051 - val_mae: 0.0557
#
# Epoch 00009: val_loss did not improve from 0.00511
# Epoch 10/100
# 48/48 [==============================] - 2s 45ms/step - loss: 0.0096 - mae: 0.0694 - val_loss: 0.0047 - val_mae: 0.0505
#
# Epoch 00010: val_loss improved from 0.00511 to 0.00474, saving model to /content/gdrive/My Drive/saved/left_eyebrow_outer_end/weights/left_eyebrow_outer_end.ckpt
# Epoch 11/100
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0080 - mae: 0.0650 - val_loss: 0.0047 - val_mae: 0.0542
#
# Epoch 00011: val_loss did not improve from 0.00474
# Epoch 12/100
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0082 - mae: 0.0645 - val_loss: 0.0036 - val_mae: 0.0439
#
# Epoch 00012: val_loss improved from 0.00474 to 0.00357, saving model to /content/gdrive/My Drive/saved/left_eyebrow_outer_end/weights/left_eyebrow_outer_end.ckpt
# Epoch 13/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0084 - mae: 0.0652 - val_loss: 0.0044 - val_mae: 0.0500
#
# Epoch 00013: val_loss did not improve from 0.00357
# Epoch 14/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0070 - mae: 0.0607 - val_loss: 0.0049 - val_mae: 0.0541
#
# Epoch 00014: val_loss did not improve from 0.00357
# Epoch 15/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0077 - mae: 0.0642 - val_loss: 0.0044 - val_mae: 0.0480
#
# Epoch 00015: val_loss did not improve from 0.00357
# Epoch 16/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0068 - mae: 0.0595 - val_loss: 0.0043 - val_mae: 0.0488
#
# Epoch 00016: val_loss did not improve from 0.00357
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 17/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0060 - mae: 0.0583 - val_loss: 0.0036 - val_mae: 0.0453
#
# Epoch 00017: val_loss did not improve from 0.00357
# Epoch 18/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0059 - mae: 0.0551 - val_loss: 0.0038 - val_mae: 0.0449
#
# Epoch 00018: val_loss did not improve from 0.00357
# Epoch 19/100
# 48/48 [==============================] - 2s 49ms/step - loss: 0.0056 - mae: 0.0538 - val_loss: 0.0031 - val_mae: 0.0410
#
# Epoch 00019: val_loss improved from 0.00357 to 0.00309, saving model to /content/gdrive/My Drive/saved/left_eyebrow_outer_end/weights/left_eyebrow_outer_end.ckpt
# Epoch 20/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0054 - mae: 0.0525 - val_loss: 0.0039 - val_mae: 0.0461
#
# Epoch 00020: val_loss did not improve from 0.00309
# Epoch 21/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0048 - mae: 0.0505 - val_loss: 0.0028 - val_mae: 0.0396
#
# Epoch 00021: val_loss improved from 0.00309 to 0.00278, saving model to /content/gdrive/My Drive/saved/left_eyebrow_outer_end/weights/left_eyebrow_outer_end.ckpt
# Epoch 22/100
# 48/48 [==============================] - 2s 49ms/step - loss: 0.0059 - mae: 0.0530 - val_loss: 0.0031 - val_mae: 0.0433
#
# Epoch 00022: val_loss did not improve from 0.00278
# Epoch 23/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0049 - mae: 0.0508 - val_loss: 0.0039 - val_mae: 0.0437
#
# Epoch 00023: val_loss did not improve from 0.00278
# Epoch 24/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0049 - mae: 0.0507 - val_loss: 0.0024 - val_mae: 0.0370
#
# Epoch 00024: val_loss improved from 0.00278 to 0.00244, saving model to /content/gdrive/My Drive/saved/left_eyebrow_outer_end/weights/left_eyebrow_outer_end.ckpt
# Epoch 25/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0050 - mae: 0.0511 - val_loss: 0.0033 - val_mae: 0.0449
#
# Epoch 00025: val_loss did not improve from 0.00244
# Epoch 26/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0055 - mae: 0.0522 - val_loss: 0.0048 - val_mae: 0.0444
#
# Epoch 00026: val_loss did not improve from 0.00244
# Epoch 27/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0054 - mae: 0.0520 - val_loss: 0.0037 - val_mae: 0.0438
#
# Epoch 00027: val_loss did not improve from 0.00244
# Epoch 28/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0049 - mae: 0.0504 - val_loss: 0.0034 - val_mae: 0.0428
#
# Epoch 00028: val_loss did not improve from 0.00244
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 29/100
# 48/48 [==============================] - 2s 50ms/step - loss: 0.0053 - mae: 0.0528 - val_loss: 0.0023 - val_mae: 0.0359
#
# Epoch 00029: val_loss improved from 0.00244 to 0.00233, saving model to /content/gdrive/My Drive/saved/left_eyebrow_outer_end/weights/left_eyebrow_outer_end.ckpt
# Epoch 30/100
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0053 - mae: 0.0513 - val_loss: 0.0027 - val_mae: 0.0376
#
# Epoch 00030: val_loss did not improve from 0.00233
# Epoch 31/100
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0050 - mae: 0.0498 - val_loss: 0.0031 - val_mae: 0.0419
#
# Epoch 00031: val_loss did not improve from 0.00233
# Epoch 32/100
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0050 - mae: 0.0496 - val_loss: 0.0026 - val_mae: 0.0380
#
# Epoch 00032: val_loss did not improve from 0.00233
# Epoch 33/100
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0050 - mae: 0.0497 - val_loss: 0.0035 - val_mae: 0.0444
#
# Epoch 00033: val_loss did not improve from 0.00233
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 34/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0040 - val_mae: 0.0432
#
# Epoch 00034: val_loss did not improve from 0.00233
# Epoch 35/100
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0046 - mae: 0.0489 - val_loss: 0.0023 - val_mae: 0.0358
#
# Epoch 00035: val_loss improved from 0.00233 to 0.00232, saving model to /content/gdrive/My Drive/saved/left_eyebrow_outer_end/weights/left_eyebrow_outer_end.ckpt
# Epoch 36/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0046 - mae: 0.0489 - val_loss: 0.0036 - val_mae: 0.0415
#
# Epoch 00036: val_loss did not improve from 0.00232
# Epoch 37/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0051 - mae: 0.0499 - val_loss: 0.0023 - val_mae: 0.0365
#
# Epoch 00037: val_loss did not improve from 0.00232
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 38/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0044 - mae: 0.0486 - val_loss: 0.0040 - val_mae: 0.0406
#
# Epoch 00038: val_loss did not improve from 0.00232
# Epoch 39/100
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0051 - mae: 0.0504 - val_loss: 0.0036 - val_mae: 0.0425
#
# Epoch 00039: val_loss did not improve from 0.00232
# Epoch 40/100
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0051 - mae: 0.0502 - val_loss: 0.0030 - val_mae: 0.0402
#
# Epoch 00040: val_loss did not improve from 0.00232
# Epoch 41/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0047 - mae: 0.0501 - val_loss: 0.0035 - val_mae: 0.0402
#
# Epoch 00041: val_loss did not improve from 0.00232
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 42/100
# 48/48 [==============================] - 2s 47ms/step - loss: 0.0047 - mae: 0.0497 - val_loss: 0.0033 - val_mae: 0.0430
#
# Epoch 00042: val_loss did not improve from 0.00232
# Epoch 43/100
# 48/48 [==============================] - 2s 48ms/step - loss: 0.0049 - mae: 0.0494 - val_loss: 0.0030 - val_mae: 0.0386
#
# Epoch 00043: val_loss did not improve from 0.00232
# Epoch 00043: early stopping

# %%
# Recreat the same structure of the model and load its saved weights then build it by predicting a random input then save the model
from src.train import compile_model
from tensorflow.keras.models import load_model

model = MySimpleModel(config.IMAGE_SHAPE, config.FEATURES_DIMENSIONS)

model.load_weights(config.WEIGHT_PATH)
model.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
model.save(config.MODEL_PATH)
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/saved/left_eyebrow_outer_end/model/assets

# %%
# load the model to check it
m = load_model(config.MODEL_PATH, compile=False)
m.predict(tf.expand_dims(tf.random.uniform(model.image_shape), axis=0))
# Out:
# array([[0.7403173 , 0.35504836]], dtype=float32)

# %%
compile_model(m)
m.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0489 - mae: 0.0306
# [0.050987180322408676, 0.03166389837861061]

# %% [markdown]
# #### **Evaluate the model**

# %%
my_model.evaluate(test_generator)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0022 - mae: 0.0315
# [0.0021549880038946867, 0.03152348846197128]

# %%
# Retrieve a list of list results on training and test data sets for each training epoch
loss     = history.history['loss']
val_loss = history.history['val_loss']
epochs   = range(len(loss))
# Plot training and validation loss per epoch
plt.plot(epochs,loss, color='red' , label='training loss')
plt.plot(epochs, val_loss, label='validation loss')
plt.legend()
plt.title ('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
test_generator_with_augmentation =  DataGenerator(df_test,
                               batch_size=config.BATCH_SIZE,
                               augment=config.AUGMENT_TRAIN,
                               shuffle=False, 
                               rgb_channels=config.RGB_CHANNELS, 
                               normalize_image=config.NORMALIZE_IMAGE,
                               normalize_coordinates=config.NORMALIZE_COORDINATES,
                               scaler=train_generator.scaler)

# %%
batch = test_generator_with_augmentation.__getitem__(0)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_augmented_results.png", "augmented")

# %%
batch = test_generator.__getitem__(0)
visualize_random_predicted_images(my_model, batch, scaler, feature_name, path+feature_name+"_normal_results.png", "normal")
